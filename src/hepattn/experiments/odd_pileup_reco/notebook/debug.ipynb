# %%
# %load_ext autoreload
# %autoreload 2

# %%
path = '/storage/agrp/barakma/PileupODD/data/dihiggs_pu200_all_vertices_chunked'
# from 00000 to 00020
val_files = ['/storage/agrp/barakma/PileupODD/data/dihiggs_pu200_all_vertices_chunked/target_particles-00000.parquet',
]

# %%
val_files = [    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00686.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00214.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00363.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00379.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00166.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00373.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00854.parquet',]

# %%
val_files=[
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00686.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00214.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00363.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00379.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00166.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00373.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00854.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00650.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00464.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00927.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00920.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00103.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00951.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00875.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00081.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00296.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00791.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00233.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00677.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00046.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00071.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00721.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00196.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00591.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00370.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00882.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00633.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00643.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00849.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00300.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00565.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00080.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00387.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00127.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00549.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00470.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00747.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00044.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00826.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00270.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00618.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00352.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00867.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00367.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00099.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00389.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00094.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00963.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00344.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00781.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00220.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00159.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00937.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00348.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00956.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00714.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00163.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00825.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00777.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00006.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00890.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00828.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00284.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00603.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00459.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00225.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00429.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00959.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00718.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00665.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00733.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00203.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00574.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00027.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00616.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00517.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00238.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00223.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00095.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00030.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00032.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00432.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00604.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00089.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00558.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00913.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00758.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00692.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00104.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00754.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00142.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00228.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00250.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00281.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00759.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00025.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00114.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00654.parquet'
]

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import run_data_plots
run_data_plots(config_path ='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml'
               ,files=val_files, num_events=1000)
# Out:
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 1000 samples
# Is inference: False
# Loading Events:   0%|                                                                                                                                | 0/1000 [00:00<?, ?evt/s]
# Processing file index 686 (File 1/98)
# Loading Events:   9%|██████████▍                                                                                                           | 88/1000 [00:00<00:02, 339.98evt/s]
# Processing file index 214 (File 2/98)
# Loading Events:  18%|█████████████████████▍                                                                                               | 183/1000 [00:00<00:04, 190.29evt/s]
# Processing file index 363 (File 3/98)
# Loading Events:  28%|████████████████████████████████▌                                                                                    | 278/1000 [00:01<00:04, 170.19evt/s]
# Processing file index 379 (File 4/98)
# Loading Events:  38%|███████████████████████████████████████████▉                                                                         | 375/1000 [00:02<00:03, 164.66evt/s]
# Processing file index 166 (File 5/98)
# Loading Events:  47%|██████████████████████████████████████████████████████▊                                                              | 469/1000 [00:02<00:03, 159.59evt/s]
# Processing file index 373 (File 6/98)
# Loading Events:  56%|██████████████████████████████████████████████████████████████████                                                   | 565/1000 [00:03<00:02, 158.54evt/s]
# Processing file index 854 (File 7/98)
# Loading Events:  66%|█████████████████████████████████████████████████████████████████████████████▏                                       | 660/1000 [00:03<00:02, 157.53evt/s]
# Processing file index 650 (File 8/98)
# Loading Events:  76%|████████████████████████████████████████████████████████████████████████████████████████▎                            | 755/1000 [00:04<00:01, 156.15evt/s]
# Processing file index 464 (File 9/98)
# Loading Events:  85%|███████████████████████████████████████████████████████████████████████████████████████████████████▏                 | 848/1000 [00:05<00:00, 154.60evt/s]
# Processing file index 927 (File 10/98)
# Loading Events:  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▋       | 938/1000 [00:05<00:00, 151.82evt/s]
# Processing file index 920 (File 11/98)
# Loading Events: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 146.87evt/s]
# --- Filtering Statistics ---
# Total events processed: 1100
# Events dropped (Too many nodes > 5500): 68
# Events dropped (Too many particles > 399): 0
# Total events kept: 1000
# ----------------------------
# Loaded 1000 events. Concatenating arrays...
# event numbers 10: [68600 68601 68602 68604 68605 68606 68607 68608 68609 68610]
# Number of events after filtering: 1000
# Track composition: Hard scatter 51906 (5.8%) | Pileup 835709 (94.2%)
# Energy composition: Total deposited HS energy 8.04e+05 | Total cluster energy 2.17e+07 | Ratio 0.0370
# --- Delta R window analysis (100 sampled events, window_size=256) ---
# Avg nodes per event: 4998
# Mean delta R within window: 0.8927  [Q1=0.8794, Q3=0.9060]
# Mean max delta R within window: 4.4876  [Q1=4.4742, Q3=4.5025]
# -------------------------------------------------------------------------
#   data/deltaR_window_analysis              0.03s
#   data/eta_window_analysis                 0.02s
#   data/phi_window_analysis                 0.03s
#   data/truth_particle_class_dist           0.09s
#   data/mask_hs_energy_efficiency           0.17s
# {'data/deltaR_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/eta_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/phi_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/truth_particle_class_dist': <Figure size 1100x500 with 1 Axes>,
#  'data/mask_hs_energy_efficiency': <Figure size 800x500 with 1 Axes>}

# %%
from hepattn.experiments.odd_pileup_reco.eval_data import  run_forward_pass        
hp_path = run_forward_pass(ckpt_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981.ckpt',
                           config_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml',
                           files=val_files,
                           num_events=2000,
                           batch_size=32,
                           test_suff='latest_256_dim',
                           inference_mode=True,
                           )
# Out:
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# Using bfloat16 Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA RTX 6000 Ada Generation') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Running test...
# ----------------------------------------------------------------------------------------------------
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 2000 samples
# Is inference: True
# Loading Events:   0%|                                                    | 0/2000 [00:00<?, ?evt/s]
# Processing file index 686 (File 1/98)
# Loading Events:   4%|█▊                                        | 87/2000 [00:00<00:13, 136.99evt/s]
# Processing file index 214 (File 2/98)
# Loading Events:   9%|███▋                                     | 182/2000 [00:01<00:13, 135.61evt/s]
# Processing file index 363 (File 3/98)
# Loading Events:  14%|█████▋                                   | 275/2000 [00:02<00:13, 131.70evt/s]
# Processing file index 379 (File 4/98)
# Loading Events:  18%|███████▌                                 | 370/2000 [00:02<00:11, 136.81evt/s]
# Processing file index 166 (File 5/98)
# Loading Events:  23%|█████████▌                               | 464/2000 [00:03<00:11, 139.15evt/s]
# Processing file index 373 (File 6/98)
# Loading Events:  28%|███████████▍                             | 560/2000 [00:04<00:10, 139.99evt/s]
# Processing file index 854 (File 7/98)
# Loading Events:  33%|█████████████▍                           | 655/2000 [00:04<00:09, 141.17evt/s]
# Processing file index 650 (File 8/98)
# Loading Events:  38%|███████████████▍                         | 750/2000 [00:05<00:08, 141.91evt/s]
# Processing file index 464 (File 9/98)
# Loading Events:  42%|█████████████████▎                       | 842/2000 [00:06<00:08, 143.56evt/s]
# Processing file index 927 (File 10/98)
# Loading Events:  47%|███████████████████                      | 931/2000 [00:06<00:07, 135.43evt/s]
# Processing file index 920 (File 11/98)
# Loading Events:  51%|████████████████████▍                   | 1023/2000 [00:07<00:07, 132.14evt/s]
# Processing file index 103 (File 12/98)
# Loading Events:  56%|██████████████████████▍                 | 1123/2000 [00:08<00:06, 137.08evt/s]
# Processing file index 951 (File 13/98)
# Loading Events:  61%|████████████████████████▎               | 1217/2000 [00:08<00:06, 130.19evt/s]
# Processing file index 875 (File 14/98)
# Loading Events:  65%|██████████████████████████▏             | 1309/2000 [00:09<00:05, 126.54evt/s]
# Processing file index 81 (File 15/98)
# Loading Events:  70%|████████████████████████████            | 1400/2000 [00:10<00:04, 122.66evt/s]
# Processing file index 296 (File 16/98)
# Loading Events:  75%|█████████████████████████████▉          | 1495/2000 [00:11<00:03, 129.06evt/s]
# Processing file index 791 (File 17/98)
# Loading Events:  79%|███████████████████████████████▋        | 1586/2000 [00:11<00:03, 127.76evt/s]
# Processing file index 233 (File 18/98)
# Loading Events:  84%|█████████████████████████████████▋      | 1684/2000 [00:12<00:02, 128.24evt/s]
# Processing file index 677 (File 19/98)
# Loading Events:  89%|███████████████████████████████████▌    | 1777/2000 [00:13<00:01, 131.00evt/s]
# Processing file index 46 (File 20/98)
# Loading Events:  94%|█████████████████████████████████████▍  | 1870/2000 [00:14<00:00, 131.38evt/s]
# Processing file index 71 (File 21/98)
# Loading Events:  98%|███████████████████████████████████████▎| 1965/2000 [00:14<00:00, 129.80evt/s]
# Processing file index 721 (File 22/98)
# Loading Events: 100%|████████████████████████████████████████| 2000/2000 [00:15<00:00, 128.04evt/s]
# --- Filtering Statistics ---
# Total events processed: 2200
# Events dropped (Too many nodes > 5500): 143
# Events dropped (Too many particles > 399): 0
# Total events kept: 2000
# ----------------------------
# Loaded 2000 events. Concatenating arrays...
# event numbers 10: [68600 68601 68602 68604 68605 68606 68607 68608 68609 68610]
# Number of events after filtering: 2000
# Track composition: Hard scatter 106133 (6.0%) | Pileup 1675106 (94.0%)
# Energy composition: Total deposited HS energy 1.62e+06 | Total cluster energy 4.32e+07 | Ratio 0.0376
# Restoring states from the checkpoint path at /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981.ckpt
# --- Delta R window analysis (100 sampled events, window_size=256) ---
# Avg nodes per event: 4950
# Mean delta R within window: 0.8955  [Q1=0.8791, Q3=0.9087]
# Mean max delta R within window: 4.4903  [Q1=4.4720, Q3=4.5081]
# -------------------------------------------------------------------------
# Created test dataset with 2,000 events
# ----------------------------------------------------------------------------------------------------
#
# Instantiating test dataloader on rank 0
# Creating test dataloader with 2,000 events
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:282: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["Checkpoint{'monitor': 'val/loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [GPU-bf936b34-3dc7-13ce-d7c5-97b330c451d0]
# Loaded model weights from the checkpoint at /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981.ckpt
# Instantiating test dataloader on rank 0
# Creating test dataloader with 2,000 events
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:425: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=5` in the `DataLoader` to improve performance.
# Testing: |                                                                   | 0/? [00:00<?, ?it/s]
# [DBG logit] key=reco_pflow_node_logit shape=(32, 400, 1400)
# [DBG logit] min=-100.00 max=26.50 mean=-78.00
# [DBG logit] isinf=0 isnan=0
# [DBG logit row0] min=-100.00 max=21.38
# [DBG target] key=reco_particle_node_valid shape=(32, 400, 1400)
# [DBG target] min=0.0000 max=1.0000 sum=53327.0
# [DBG target] >1: 0  <0: 0
# [DBG target row0] sum=41099.0 max=1.0000
# [DBG node_valid] valid_per_sample: min=128 max=667 mean=358.9
# [DBG node_valid] any_zero_rows=False
# Wrote predictions to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981__test_latest_256_dim.h5
# Loading predictions...
# Writing to ROOT file
# Wrote ROOT file to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981__test_latest_256_dim.root
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                Test metric                 ┃                DataLoader 0                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/calo_final_calo_mask_mask_bce     │             0.3942023515701294             │
# │   test/calo_final_calo_mask_mask_tversky   │              2.05707049369812              │
# │            test/calo_final_loss            │             2.451273202896118              │
# │             test/calo_mask_f1              │             0.5727814435958862             │
# │          test/calo_mask_precision          │             0.4836120307445526             │
# │           test/calo_mask_recall            │             0.7022669911384583             │
# │                 test/loss                  │             14.164543151855469             │
# │               test/reco_eff                │             0.6998235583305359             │
# │  test/reco_final_classification_object_ce  │             1.4252114295959473             │
# │      test/reco_final_incidence_kl_div      │            0.005857809912413359            │
# │            test/reco_final_loss            │             2.6745126247406006             │
# │       test/reco_final_mask_mask_bce        │             0.5999071002006531             │
# │       test/reco_final_mask_mask_dice       │             0.2955096662044525             │
# │       test/reco_final_regression_l1        │            0.34802761673927307             │
# │ test/reco_layer_0_classification_object_ce │             0.6209098100662231             │
# │           test/reco_layer_0_loss           │             1.642180323600769              │
# │      test/reco_layer_0_mask_mask_bce       │             0.6360605359077454             │
# │      test/reco_layer_0_mask_mask_dice      │            0.38520994782447815             │
# │ test/reco_layer_1_classification_object_ce │             1.0512946844100952             │
# │           test/reco_layer_1_loss           │             2.0313239097595215             │
# │      test/reco_layer_1_mask_mask_bce       │             0.6232961416244507             │
# │      test/reco_layer_1_mask_mask_dice      │             0.356732577085495              │
# │ test/reco_layer_2_classification_object_ce │             1.207097053527832              │
# │           test/reco_layer_2_loss           │             2.1390528678894043             │
# │      test/reco_layer_2_mask_mask_bce       │             0.6118150353431702             │
# │      test/reco_layer_2_mask_mask_dice      │            0.32014045119285583             │
# │ test/reco_layer_3_classification_object_ce │             1.350195050239563              │
# │           test/reco_layer_3_loss           │             2.2547810077667236             │
# │      test/reco_layer_3_mask_mask_bce       │             0.6045481562614441             │
# │      test/reco_layer_3_mask_mask_dice      │             0.3000375032424927             │
# │           test/reco_mask_purity            │             0.5867888331413269             │
# │           test/reco_mask_recall            │             0.6318984627723694             │
# │     test/reco_obj_class_accuracy_macro     │             0.6892797946929932             │
# │     test/reco_obj_class_accuracy_micro     │             0.8531187772750854             │
# │               test/reco_pur                │             0.9057035446166992             │
# │               test/track_f1                │             0.9038896560668945             │
# │           test/track_final_loss            │            0.18621383607387543             │
# │       test/track_final_mask_mask_bce       │            0.034773435443639755            │
# │      test/track_final_mask_mask_dice       │            0.10383404046297073             │
# │  test/track_final_vz_regression_smooth_l1  │            0.04760632663965225             │
# │          test/track_layer_0_loss           │            0.33026599884033203             │
# │      test/track_layer_0_mask_mask_bce      │            0.07595844566822052             │
# │     test/track_layer_0_mask_mask_dice      │             0.2543075382709503             │
# │          test/track_layer_1_loss           │            0.17532780766487122             │
# │      test/track_layer_1_mask_mask_bce      │            0.04398439824581146             │
# │     test/track_layer_1_mask_mask_dice      │            0.13134340941905975             │
# │          test/track_layer_2_loss           │            0.14071601629257202             │
# │      test/track_layer_2_mask_mask_bce      │            0.033834923058748245            │
# │     test/track_layer_2_mask_mask_dice      │            0.10688110440969467             │
# │          test/track_layer_3_loss           │            0.13889352977275848             │
# │      test/track_layer_3_mask_mask_bce      │             0.0345388762652874             │
# │     test/track_layer_3_mask_mask_dice      │            0.10435467213392258             │
# │            test/track_precision            │             0.9193292260169983             │
# │             test/track_recall              │             0.888960063457489              │
# │                test/vz_mae                 │             4.435699462890625              │
# └────────────────────────────────────────────┴────────────────────────────────────────────┘
# Predictions written to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981__test_latest_256_dim.h5

# %%
from pathlib import Path
from hepattn.experiments.odd_pileup_reco.eval_data import run_forward_pass, load_eval_data_from_h5
from hepattn.experiments.odd_pileup_reco.reco_analysis import run_reco_analysis, pflow_data_from_eval_dicts

CKPT_PATH = "/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560.ckpt"
CONFIG_PATH = "/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml"
N_EVENTS = 1000
BATCH_SIZE = 64
BASE_TAG = "apr15_debug_true_mask_compare"

baseline_suff = f"{BASE_TAG}_predmask_n{N_EVENTS}"
debug_suff = f"{BASE_TAG}_truthmask_n{N_EVENTS}"

print("Running baseline forward pass...")
h5_baseline = run_forward_pass(
    ckpt_path=CKPT_PATH,
    config_path=CONFIG_PATH,
    files=val_files,
    num_events=N_EVENTS,
    batch_size=BATCH_SIZE,
    test_suff=baseline_suff,
    inference_mode=True,
    reco_debug_use_truth_masks=False,
    )

print("Running debug forward pass with truth masks in reco filtering...")
h5_debug = run_forward_pass(
    ckpt_path=CKPT_PATH,
    config_path=CONFIG_PATH,
    files=val_files,
    num_events=N_EVENTS,
    batch_size=BATCH_SIZE,
    test_suff=debug_suff,
    inference_mode=True,
    reco_debug_use_truth_masks=True,
    )

print("Baseline H5:", h5_baseline)
print("Debug H5:   ", h5_debug)
print("Baseline file name:", Path(h5_baseline).name)
print("Debug file name:   ", Path(h5_debug).name)

_, _, reco_baseline = load_eval_data_from_h5(h5_baseline, event_start=0, event_stop=N_EVENTS)
_, _, reco_debug = load_eval_data_from_h5(h5_debug, event_start=0, event_stop=N_EVENTS)

data_baseline = pflow_data_from_eval_dicts(reco_baseline)
data_debug = pflow_data_from_eval_dicts(reco_debug)
# Out:
# Running baseline forward pass...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 15
#      12 debug_suff = f"{BASE_TAG}_truthmask_n{N_EVENTS}"
#      14 print("Running baseline forward pass...")
# ---> 15 h5_baseline = run_forward_pass(
#      16     ckpt_path=CKPT_PATH,
#      17     config_path=CONFIG_PATH,
#      18     files=val_files,
#      19     num_events=N_EVENTS,
#      20     batch_size=BATCH_SIZE,
#      21     test_suff=baseline_suff,
#      22     inference_mode=True,
#      23     reco_debug_use_truth_masks=False,
#      24     )
#      26 print("Running debug forward pass with truth masks in reco filtering...")
#      27 h5_debug = run_forward_pass(
#      28     ckpt_path=CKPT_PATH,
#      29     config_path=CONFIG_PATH,
#    (...)
#      35     reco_debug_use_truth_masks=True,
#      36     )
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/eval_data.py:533, in run_forward_pass(ckpt_path, config_path, data_dir, files, num_events, batch_size, num_workers, accelerator, devices, precision, inference_mode, reco_debug_use_truth_masks, test_suff)
#     512 datamodule = ODDDataModule(
#     513     train_path=filepath,
#     514     valid_path=filepath,
#    (...)
#     529     enable_split=False,
#     530 )
#     532 # Load model
# --> 533 model = ODDPFlowTwoStream.load_from_checkpoint(str(ckpt_path), map_location="cpu")
#     534 if hasattr(model, "model") and hasattr(model.model, "reco_debug_use_truth_masks"):
#     535     model.model.reco_debug_use_truth_masks = bool(reco_debug_use_truth_masks)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/utilities/model_helpers.py:125, in _restricted_classmethod_impl.__get__.<locals>.wrapper(*args, **kwargs)
#     120 if instance is not None and not is_scripting:
#     121     raise TypeError(
#     122         f"The classmethod `{cls.__name__}.{self.method.__name__}` cannot be called on an instance."
#     123         " Please call it on the class type and make sure the return value is used."
#     124     )
# --> 125 return self.method(cls, *args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/core/module.py:1581, in LightningModule.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#    1492 @_restricted_classmethod
#    1493 def load_from_checkpoint(
#    1494     cls,
#    (...)
#    1499     **kwargs: Any,
#    1500 ) -> Self:
#    1501     r"""Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint it stores the arguments
#    1502     passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    1503
#    (...)
#    1579
#    1580     """
# -> 1581     loaded = _load_from_checkpoint(
#    1582         cls,
#    1583         checkpoint_path,
#    1584         map_location,
#    1585         hparams_file,
#    1586         strict,
#    1587         **kwargs,
#    1588     )
#    1589     return cast(Self, loaded)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/core/saving.py:91, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      89     return _load_state(cls, checkpoint, **kwargs)
#      90 if issubclass(cls, pl.LightningModule):
# ---> 91     model = _load_state(cls, checkpoint, strict=strict, **kwargs)
#      92     state_dict = checkpoint["state_dict"]
#      93     if not state_dict:
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/core/saving.py:165, in _load_state(cls, checkpoint, strict, **cls_kwargs_new)
#     161 if not cls_spec.varkw:
#     162     # filter kwargs according to class init unless it allows any argument via kwargs
#     163     _cls_kwargs = {k: v for k, v in _cls_kwargs.items() if k in cls_init_args_name}
# --> 165 obj = instantiator(cls, _cls_kwargs) if instantiator else cls(**_cls_kwargs)
#     167 if isinstance(obj, pl.LightningDataModule):
#     168     if obj.__class__.__qualname__ in checkpoint:
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/cli.py:828, in instantiate_module(class_type, config)
#     826 else:
#     827     parser.add_class_arguments(class_type, "module", fail_untyped=False)
# --> 828 cfg = parser.parse_object({"module": config})
#     829 init = parser.instantiate_classes(cfg)
#     830 return init.module
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_deprecated.py:145, in parse_as_dict_patch.<locals>.patch_parse_method.<locals>.patched_parse(self, with_meta, _skip_validation, *args, **kwargs)
#     137 def patched_parse(
#     138     self,
#     139     *args,
#    (...)
#     142     **kwargs,
#     143 ) -> Union[Namespace, Dict[str, Any]]:
#     144     parse_method = getattr(self, unpatched_method_name)
# --> 145     cfg = parse_method(*args, _skip_validation=_skip_validation, **kwargs)
#     147     if isinstance(with_meta, bool):
#     148         deprecation_warning(patched_parse, message_with_meta)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:499, in ArgumentParser.parse_object(self, cfg_obj, cfg_base, env, defaults, **kwargs)
#     496     cfg_apply = self._apply_actions(cfg_obj, prev_cfg=cfg)
#     497     cfg = self.merge_config(cfg_apply, cfg)
# --> 499     parsed_cfg = self._parse_common(
#     500         cfg=cfg,
#     501         env=env,
#     502         defaults=defaults,
#     503         skip_validation=skip_validation,
#     504         skip_required=skip_required,
#     505     )
#     507 except (TypeError, KeyError) as ex:
#     508     self.error(str(ex), ex)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:369, in ArgumentParser._parse_common(self, cfg, env, defaults, skip_validation, skip_required, skip_subcommands, fail_no_subcommand)
#     367 if defaults:
#     368     with parser_context(lenient_check=True):
# --> 369         ActionTypeHint.add_sub_defaults(self, cfg)
#     371 with parser_context(parent_parser=self):
#     372     if not lenient_check.get() and self.parser_mode == "omegaconf+":
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:477, in ActionTypeHint.add_sub_defaults(parser, cfg)
#     469     return not (
#     470         isinstance(v, (str, Namespace))
#     471         or is_subclass_spec(v)
#     472         or (isinstance(v, list) and any(is_subclass_spec(e) for e in v))
#     473         or (isinstance(v, dict) and any(is_subclass_spec(e) for e in v.values()))
#     474     )
#     476 with ActionTypeHint.sub_defaults_context(), parent_parsers_context(None, None):
# --> 477     parser._apply_actions(cfg, skip_fn=skip_sub_defaults_apply, prev_cfg=cfg.clone())
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1394, in ArgumentParser._apply_actions(self, cfg, parent_key, prev_cfg, skip_fn)
#    1392     continue
#    1393 with parser_context(parent_parser=self, lenient_check=True):
# -> 1394     value = self._check_value_key(action, value, action_dest, prev_cfg, append=append)
#    1395 if isinstance(action, _ActionConfigLoad):
#    1396     config_keys.add(action_dest)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1454, in ArgumentParser._check_value_key(self, action, value, key, cfg, append)
#    1452 elif hasattr(action, "_check_type"):
#    1453     with parser_context(parent_parser=self):
# -> 1454         value = action._check_type_(value, cfg=cfg, append=append, mode=self.parser_mode)  # type: ignore[attr-defined]
#    1455 elif action.type is not None:
#    1456     try:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_common.py:429, in Action._check_type_(self, value, **kwargs)
#     427     self._check_type_kwargs = set(inspect.signature(self._check_type).parameters)
#     428 kwargs = {k: v for k, v in kwargs.items() if k in self._check_type_kwargs}
# --> 429 return self._check_type(value, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:576, in ActionTypeHint._check_type(self, value, append, cfg, mode)
#     574 try:
#     575     with change_to_path_dir(config_path):
# --> 576         val = adapt_typehints(val, self._typehint, **kwargs)
#     577 except ValueError as ex:
#     578     assert ex  # needed due to ruff bug that removes " as ex"
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1100, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#    1098         raise_unexpected_value(f"Import path {val['class_path']} does not {msg} {typehint.__name__}")
#    1099     val["class_path"] = class_path
# -> 1100     val = adapt_class_type(
#    1101         val,
#    1102         serialize,
#    1103         instantiate_classes,
#    1104         sub_add_kwargs,
#    1105         prev_val=prev_val,
#    1106         typehint=typehint,
#    1107     )
#    1108 except (ImportError, AttributeError, AssertionError, ArgumentError) as ex:
#    1109     class_path = val if isinstance(val, str) else val["class_path"]
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1518, in adapt_class_type(value, serialize, instantiate_classes, sub_add_kwargs, prev_val, partial_skip_args, typehint)
#    1516     init_args["dict_kwargs"] = dict_kwargs
#    1517     dict_kwargs = None
# -> 1518 init_args = parser.parse_object(init_args, cfg_base=prev_init_args, defaults=sub_defaults.get())
#    1519 if init_args:
#    1520     value["init_args"] = init_args
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_deprecated.py:145, in parse_as_dict_patch.<locals>.patch_parse_method.<locals>.patched_parse(self, with_meta, _skip_validation, *args, **kwargs)
#     137 def patched_parse(
#     138     self,
#     139     *args,
#    (...)
#     142     **kwargs,
#     143 ) -> Union[Namespace, Dict[str, Any]]:
#     144     parse_method = getattr(self, unpatched_method_name)
# --> 145     cfg = parse_method(*args, _skip_validation=_skip_validation, **kwargs)
#     147     if isinstance(with_meta, bool):
#     148         deprecation_warning(patched_parse, message_with_meta)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:496, in ArgumentParser.parse_object(self, cfg_obj, cfg_base, env, defaults, **kwargs)
#     493     cfg = self.merge_config(cfg_base, cfg)
#     495 cfg = self._apply_actions(cfg)
# --> 496 cfg_apply = self._apply_actions(cfg_obj, prev_cfg=cfg)
#     497 cfg = self.merge_config(cfg_apply, cfg)
#     499 parsed_cfg = self._parse_common(
#     500     cfg=cfg,
#     501     env=env,
#    (...)
#     504     skip_required=skip_required,
#     505 )
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1394, in ArgumentParser._apply_actions(self, cfg, parent_key, prev_cfg, skip_fn)
#    1392     continue
#    1393 with parser_context(parent_parser=self, lenient_check=True):
# -> 1394     value = self._check_value_key(action, value, action_dest, prev_cfg, append=append)
#    1395 if isinstance(action, _ActionConfigLoad):
#    1396     config_keys.add(action_dest)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1454, in ArgumentParser._check_value_key(self, action, value, key, cfg, append)
#    1452 elif hasattr(action, "_check_type"):
#    1453     with parser_context(parent_parser=self):
# -> 1454         value = action._check_type_(value, cfg=cfg, append=append, mode=self.parser_mode)  # type: ignore[attr-defined]
#    1455 elif action.type is not None:
#    1456     try:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_common.py:429, in Action._check_type_(self, value, **kwargs)
#     427     self._check_type_kwargs = set(inspect.signature(self._check_type).parameters)
#     428 kwargs = {k: v for k, v in kwargs.items() if k in self._check_type_kwargs}
# --> 429 return self._check_type(value, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:576, in ActionTypeHint._check_type(self, value, append, cfg, mode)
#     574 try:
#     575     with change_to_path_dir(config_path):
# --> 576         val = adapt_typehints(val, self._typehint, **kwargs)
#     577 except ValueError as ex:
#     578     assert ex  # needed due to ruff bug that removes " as ex"
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1100, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#    1098         raise_unexpected_value(f"Import path {val['class_path']} does not {msg} {typehint.__name__}")
#    1099     val["class_path"] = class_path
# -> 1100     val = adapt_class_type(
#    1101         val,
#    1102         serialize,
#    1103         instantiate_classes,
#    1104         sub_add_kwargs,
#    1105         prev_val=prev_val,
#    1106         typehint=typehint,
#    1107     )
#    1108 except (ImportError, AttributeError, AssertionError, ArgumentError) as ex:
#    1109     class_path = val if isinstance(val, str) else val["class_path"]
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1518, in adapt_class_type(value, serialize, instantiate_classes, sub_add_kwargs, prev_val, partial_skip_args, typehint)
#    1516     init_args["dict_kwargs"] = dict_kwargs
#    1517     dict_kwargs = None
# -> 1518 init_args = parser.parse_object(init_args, cfg_base=prev_init_args, defaults=sub_defaults.get())
#    1519 if init_args:
#    1520     value["init_args"] = init_args
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_deprecated.py:145, in parse_as_dict_patch.<locals>.patch_parse_method.<locals>.patched_parse(self, with_meta, _skip_validation, *args, **kwargs)
#     137 def patched_parse(
#     138     self,
#     139     *args,
#    (...)
#     142     **kwargs,
#     143 ) -> Union[Namespace, Dict[str, Any]]:
#     144     parse_method = getattr(self, unpatched_method_name)
# --> 145     cfg = parse_method(*args, _skip_validation=_skip_validation, **kwargs)
#     147     if isinstance(with_meta, bool):
#     148         deprecation_warning(patched_parse, message_with_meta)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:499, in ArgumentParser.parse_object(self, cfg_obj, cfg_base, env, defaults, **kwargs)
#     496     cfg_apply = self._apply_actions(cfg_obj, prev_cfg=cfg)
#     497     cfg = self.merge_config(cfg_apply, cfg)
# --> 499     parsed_cfg = self._parse_common(
#     500         cfg=cfg,
#     501         env=env,
#     502         defaults=defaults,
#     503         skip_validation=skip_validation,
#     504         skip_required=skip_required,
#     505     )
#     507 except (TypeError, KeyError) as ex:
#     508     self.error(str(ex), ex)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:369, in ArgumentParser._parse_common(self, cfg, env, defaults, skip_validation, skip_required, skip_subcommands, fail_no_subcommand)
#     367 if defaults:
#     368     with parser_context(lenient_check=True):
# --> 369         ActionTypeHint.add_sub_defaults(self, cfg)
#     371 with parser_context(parent_parser=self):
#     372     if not lenient_check.get() and self.parser_mode == "omegaconf+":
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:477, in ActionTypeHint.add_sub_defaults(parser, cfg)
#     469     return not (
#     470         isinstance(v, (str, Namespace))
#     471         or is_subclass_spec(v)
#     472         or (isinstance(v, list) and any(is_subclass_spec(e) for e in v))
#     473         or (isinstance(v, dict) and any(is_subclass_spec(e) for e in v.values()))
#     474     )
#     476 with ActionTypeHint.sub_defaults_context(), parent_parsers_context(None, None):
# --> 477     parser._apply_actions(cfg, skip_fn=skip_sub_defaults_apply, prev_cfg=cfg.clone())
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1394, in ArgumentParser._apply_actions(self, cfg, parent_key, prev_cfg, skip_fn)
#    1392     continue
#    1393 with parser_context(parent_parser=self, lenient_check=True):
# -> 1394     value = self._check_value_key(action, value, action_dest, prev_cfg, append=append)
#    1395 if isinstance(action, _ActionConfigLoad):
#    1396     config_keys.add(action_dest)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1454, in ArgumentParser._check_value_key(self, action, value, key, cfg, append)
#    1452 elif hasattr(action, "_check_type"):
#    1453     with parser_context(parent_parser=self):
# -> 1454         value = action._check_type_(value, cfg=cfg, append=append, mode=self.parser_mode)  # type: ignore[attr-defined]
#    1455 elif action.type is not None:
#    1456     try:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_common.py:429, in Action._check_type_(self, value, **kwargs)
#     427     self._check_type_kwargs = set(inspect.signature(self._check_type).parameters)
#     428 kwargs = {k: v for k, v in kwargs.items() if k in self._check_type_kwargs}
# --> 429 return self._check_type(value, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:576, in ActionTypeHint._check_type(self, value, append, cfg, mode)
#     574 try:
#     575     with change_to_path_dir(config_path):
# --> 576         val = adapt_typehints(val, self._typehint, **kwargs)
#     577 except ValueError as ex:
#     578     assert ex  # needed due to ruff bug that removes " as ex"
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:848, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#     846 for subtype in sorted_subtypes:
#     847     try:
# --> 848         vals.append(adapt_typehints(val, subtype, **adapt_kwargs))
#     849         break
#     850     except Exception as ex:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:909, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#     907                 adapt_kwargs_n = deepcopy(adapt_kwargs)
#     908             with change_to_path_dir(list_path):
# --> 909                 val[n] = adapt_typehints(v, subtypehints[0], **adapt_kwargs_n)
#     911 # Dict, Mapping
#     912 elif typehint_origin in mapping_origin_types:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1100, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#    1098         raise_unexpected_value(f"Import path {val['class_path']} does not {msg} {typehint.__name__}")
#    1099     val["class_path"] = class_path
# -> 1100     val = adapt_class_type(
#    1101         val,
#    1102         serialize,
#    1103         instantiate_classes,
#    1104         sub_add_kwargs,
#    1105         prev_val=prev_val,
#    1106         typehint=typehint,
#    1107     )
#    1108 except (ImportError, AttributeError, AssertionError, ArgumentError) as ex:
#    1109     class_path = val if isinstance(val, str) else val["class_path"]
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1518, in adapt_class_type(value, serialize, instantiate_classes, sub_add_kwargs, prev_val, partial_skip_args, typehint)
#    1516     init_args["dict_kwargs"] = dict_kwargs
#    1517     dict_kwargs = None
# -> 1518 init_args = parser.parse_object(init_args, cfg_base=prev_init_args, defaults=sub_defaults.get())
#    1519 if init_args:
#    1520     value["init_args"] = init_args
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_deprecated.py:145, in parse_as_dict_patch.<locals>.patch_parse_method.<locals>.patched_parse(self, with_meta, _skip_validation, *args, **kwargs)
#     137 def patched_parse(
#     138     self,
#     139     *args,
#    (...)
#     142     **kwargs,
#     143 ) -> Union[Namespace, Dict[str, Any]]:
#     144     parse_method = getattr(self, unpatched_method_name)
# --> 145     cfg = parse_method(*args, _skip_validation=_skip_validation, **kwargs)
#     147     if isinstance(with_meta, bool):
#     148         deprecation_warning(patched_parse, message_with_meta)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:496, in ArgumentParser.parse_object(self, cfg_obj, cfg_base, env, defaults, **kwargs)
#     493     cfg = self.merge_config(cfg_base, cfg)
#     495 cfg = self._apply_actions(cfg)
# --> 496 cfg_apply = self._apply_actions(cfg_obj, prev_cfg=cfg)
#     497 cfg = self.merge_config(cfg_apply, cfg)
#     499 parsed_cfg = self._parse_common(
#     500     cfg=cfg,
#     501     env=env,
#    (...)
#     504     skip_required=skip_required,
#     505 )
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1394, in ArgumentParser._apply_actions(self, cfg, parent_key, prev_cfg, skip_fn)
#    1392     continue
#    1393 with parser_context(parent_parser=self, lenient_check=True):
# -> 1394     value = self._check_value_key(action, value, action_dest, prev_cfg, append=append)
#    1395 if isinstance(action, _ActionConfigLoad):
#    1396     config_keys.add(action_dest)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_core.py:1454, in ArgumentParser._check_value_key(self, action, value, key, cfg, append)
#    1452 elif hasattr(action, "_check_type"):
#    1453     with parser_context(parent_parser=self):
# -> 1454         value = action._check_type_(value, cfg=cfg, append=append, mode=self.parser_mode)  # type: ignore[attr-defined]
#    1455 elif action.type is not None:
#    1456     try:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_common.py:429, in Action._check_type_(self, value, **kwargs)
#     427     self._check_type_kwargs = set(inspect.signature(self._check_type).parameters)
#     428 kwargs = {k: v for k, v in kwargs.items() if k in self._check_type_kwargs}
# --> 429 return self._check_type(value, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:576, in ActionTypeHint._check_type(self, value, append, cfg, mode)
#     574 try:
#     575     with change_to_path_dir(config_path):
# --> 576         val = adapt_typehints(val, self._typehint, **kwargs)
#     577 except ValueError as ex:
#     578     assert ex  # needed due to ruff bug that removes " as ex"
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1100, in adapt_typehints(val, typehint, serialize, instantiate_classes, prev_val, orig_val, append, enable_path, sub_add_kwargs, default, logger)
#    1098         raise_unexpected_value(f"Import path {val['class_path']} does not {msg} {typehint.__name__}")
#    1099     val["class_path"] = class_path
# -> 1100     val = adapt_class_type(
#    1101         val,
#    1102         serialize,
#    1103         instantiate_classes,
#    1104         sub_add_kwargs,
#    1105         prev_val=prev_val,
#    1106         typehint=typehint,
#    1107     )
#    1108 except (ImportError, AttributeError, AssertionError, ArgumentError) as ex:
#    1109     class_path = val if isinstance(val, str) else val["class_path"]
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:1456, in adapt_class_type(value, serialize, instantiate_classes, sub_add_kwargs, prev_val, partial_skip_args, typehint)
#    1454 else:
#    1455     val_class = import_object(value.class_path)
# -> 1456 parser = ActionTypeHint.get_class_parser(val_class, sub_add_kwargs, skip_args=partial_skip_args)
#    1458 # No need to re-create the linked arg but just "inform" the corresponding parser actions that it exists upstream.
#    1459 for target in sub_add_kwargs.get("linked_targets", []):
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_typehints.py:650, in ActionTypeHint.get_class_parser(val_class, sub_add_kwargs, skip_args)
#     648 remove_actions(parser, (ActionConfigFile, _ActionPrintConfig))
#     649 if inspect.isclass(val_class) or inspect.isclass(get_typehint_origin(val_class)):
# --> 650     parser.add_class_arguments(val_class, **kwargs)
#     651 else:
#     652     kwargs = {k: v for k, v in kwargs.items() if k != "instantiate"}
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_signatures.py:101, in SignatureArguments.add_class_arguments(self, theclass, nested_key, as_group, as_positional, default, skip, instantiate, fail_untyped, sub_configs, **kwargs)
#      91     raise ValueError(
#      92         f"Expected 'default' to be dict, Namespace, lazy instance or dataclass-like, got: {default}"
#      93     )
#      94 linked_targets, help_, _ = get_private_kwargs(
#      95     kwargs,
#      96     linked_targets=None,
#      97     help=None,
#      98     required=None,  # Ignored because provided when adding signatures, remove with dataclass inheritance support
#      99 )
# --> 101 added_args = self._add_signature_arguments(
#     102     theclass,
#     103     None,
#     104     nested_key,
#     105     as_group,
#     106     as_positional,
#     107     skip,
#     108     fail_untyped,
#     109     sub_configs=sub_configs,
#     110     instantiate=instantiate,
#     111     linked_targets=linked_targets,
#     112     help=help_,
#     113 )
#     115 if default:
#     116     skip = skip or set()
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_signatures.py:304, in SignatureArguments._add_signature_arguments(self, function_or_class, method_name, nested_key, as_group, as_positional, skip, fail_untyped, sub_configs, instantiate, linked_targets, help)
#     302 added_args: list[str] = []
#     303 for param in params:
# --> 304     self._add_signature_parameter(
#     305         container,
#     306         nested_key,
#     307         param,
#     308         added_args,
#     309         skip={s for s in (skip or []) if isinstance(s, str)},
#     310         fail_untyped=fail_untyped,
#     311         sub_configs=sub_configs,
#     312         linked_targets=linked_targets,
#     313         as_positional=as_positional,
#     314     )
#     316 return added_args
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_signatures.py:359, in SignatureArguments._add_signature_parameter(self, container, nested_key, param, added_args, skip, fail_untyped, as_positional, sub_configs, instantiate, linked_targets, default, **kwargs)
#     357 else:
#     358     raise RuntimeError(f"The code should never reach here: kind={kind}")  # pragma: no cover
# --> 359 src = get_parameter_origins(param.component, param.parent)
#     360 skip_message = f'Skipping parameter "{name}" from "{src}" because of: '
#     361 if not fail_untyped and annotation == inspect_empty:
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_parameter_resolvers.py:84, in get_parameter_origins(component, parent)
#      81 def get_parameter_origins(component, parent) -> Optional[str]:
#      82     from ._typehints import get_subclass_types, sequence_origin_types
# ---> 84     if get_typehint_origin(component) in sequence_origin_types:
#      85         component = get_subclass_types(component, also_lists=True)
#      86     if isinstance(component, tuple):
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_util.py:232, in get_typehint_origin(typehint)
#     230 def get_typehint_origin(typehint):
#     231     if not hasattr(typehint, "__origin__"):
# --> 232         typehint_class = get_import_path(typehint.__class__)
#     233         if typehint_class == "types.UnionType":
#     234             return Union
#
# File ~/.local/lib/python3.11/site-packages/jsonargparse/_util.py:190, in get_import_path(value)
#     187     if path:
#     188         module_path, _ = path.rsplit(".", 1)
#     189 elif (not qualname and not inspect.isclass(value)) or (
# --> 190     inspect.ismethod(value) and not inspect.isclass(value.__self__)
#     191 ):
#     192     path = get_module_var_path(module_path, value)
#     193 elif qualname:
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/inspect.py:300, in ismethod(object)
#     293     """Return true if the object is a class.
#     294
#     295     Class objects provide these attributes:
#     296         __doc__         documentation string
#     297         __module__      name of module in which this class was defined"""
#     298     return isinstance(object, type)
# --> 300 def ismethod(object):
#     301     """Return true if the object is an instance method.
#     302
#     303     Instance method objects provide these attributes:
#    (...)
#     306         __func__        function object containing implementation of method
#     307         __self__        instance to which this method is bound"""
#     308     return isinstance(object, types.MethodType)
#
# KeyboardInterrupt:

# %%
from pathlib import Path
from hepattn.experiments.odd_pileup_reco.eval_data import run_forward_pass, load_eval_data_from_h5
from hepattn.experiments.odd_pileup_reco.reco_analysis import run_reco_analysis, pflow_data_from_eval_dicts

h5_trackfilter = '/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260421-T104425/ckpts/epoch=099-val_loss=13.99981__test_latest_256_dim.h5'
_, _, reco_trackfilter = load_eval_data_from_h5(h5_trackfilter, event_start=0, event_stop=2000)

data_trackfilter = pflow_data_from_eval_dicts(reco_trackfilter)
figs_compare = run_reco_analysis(
    data_trackfilter)
# Out:
# Calo mask purity…
#   reco_analysis/calo_mask_hs_energy_purity           0.75s
# Particle-level plots…
#   reco_analysis/class_distribution                   0.06s
#   reco_analysis/n_particles                          0.04s
#   reco_analysis/n_particles_by_pt_bin                0.30s
#   reco_analysis/feature_distributions                0.57s
#   reco_analysis/feature_scatter                      1.13s
#   reco_analysis/ptetaphi_residuals                   0.86s
#   reco_analysis/pt_residual_absolute                 0.28s
#   reco_analysis/extra_particles_pt1to2               0.33s
#   reco_analysis/pileup_token_incidence_value_hist    0.21s
#   reco_analysis/incidence_heatmap                    0.06s
#   reco_analysis/incidence_diff                       0.05s
#   reco_analysis/incidence_track_match                0.07s
# Clustering jets…
# Jets (pflow): 100%|██████████| 2000/2000 [00:00<00:00, 2390.76it/s]
# Jets (truth): 100%|██████████| 2000/2000 [00:01<00:00, 1909.68it/s]
#   reco_analysis/jet_multiplicity                     0.03s
# Jet resolution…
# Matching jets: 100%|██████████| 2000/2000 [00:00<00:00, 36178.85it/s]
#   reco_analysis/jet_resolution                       0.43s
# Jets (calo): 100%|██████████| 2000/2000 [00:31<00:00, 63.22it/s]
# Jets (calo-hs): 100%|██████████| 2000/2000 [00:02<00:00, 824.09it/s]
# Matching jets: 100%|██████████| 2000/2000 [00:00<00:00, 35724.33it/s]
# Matching jets: 100%|██████████| 2000/2000 [00:00<00:00, 31249.12it/s]
# Matching jets: 100%|██████████| 2000/2000 [00:00<00:00, 36435.93it/s]
#   reco_analysis/jet_resolution_with_calo             35.01s
# Matching jets: 100%|██████████| 2000/2000 [00:00<00:00, 36198.99it/s]
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/reco_analysis.py:2447: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   tr_pf, pf_ix, _ = match_jets(
#   reco_analysis/jet_resolution_truth_pt_* (5 bins) 1.42s
#   reco_analysis/event_display_0                      0.05s
#   reco_analysis/event_split_0                        0.08s
# Done — 23 plots generated.

# %% [markdown]
# ## track  filtering affect - not big

# %%
from pathlib import Path
from hepattn.experiments.odd_pileup_reco.eval_data import run_forward_pass, load_eval_data_from_h5
from hepattn.experiments.odd_pileup_reco.reco_analysis import run_reco_analysis, pflow_data_from_eval_dicts

h5_trackfilter = '/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_update_yes_track_filter.h5'
_, _, reco_trackfilter = load_eval_data_from_h5(h5_trackfilter, event_start=0, event_stop=1000)

data_trackfilter = pflow_data_from_eval_dicts(reco_trackfilter)
figs_compare = run_reco_analysis(
    data_trackfilter)
# Out:
# Particle-level plots…
#   reco_analysis/class_distribution                   0.10s
#   reco_analysis/n_particles                          0.04s
#   reco_analysis/n_particles_by_pt_bin                0.50s
#   reco_analysis/feature_distributions                0.51s
#   reco_analysis/feature_scatter                      0.32s
#   reco_analysis/ptetaphi_residuals                   0.98s
#   reco_analysis/pt_residual_absolute                 0.26s
#   reco_analysis/extra_particles_pt1to2               0.36s
#   reco_analysis/pileup_token_incidence_value_hist    0.15s
#   reco_analysis/incidence_heatmap                    0.06s
#   reco_analysis/incidence_diff                       0.05s
#   reco_analysis/incidence_track_match                0.07s
# Clustering jets…
# Jets (pflow):   0%|                                                                                                                                   | 0/1000 [00:00<?, ?it/s]
# #--------------------------------------------------------------------------
# #                         FastJet release 3.4.0
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Jets (pflow): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1502.56it/s]
# Jets (truth): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1883.12it/s]
#   reco_analysis/jet_multiplicity                     0.04s
# Jet resolution…
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 34706.69it/s]
#   reco_analysis/jet_resolution                       0.38s
# Jets (calo): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:14<00:00, 66.74it/s]
# Jets (calo-hs): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 856.84it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 34598.48it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 30885.89it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 36120.12it/s]
#   reco_analysis/jet_resolution_with_calo             16.81s
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 34865.95it/s]
#   reco_analysis/jet_resolution_truth_pt_* (5 bins) 1.15s
#   reco_analysis/event_display_0                      0.05s
#   reco_analysis/event_split_0                        0.08s
# Done — 22 plots generated.
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/reco_analysis.py:2524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(8, 7))

# %% [markdown]
# ## jets comparison

# %%
N_EVENTS = 1000
_, _, reco_baseline = load_eval_data_from_h5('/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_apr15_debug_true_mask_compare_predmask_n1000.h5',
                                              event_start=0, event_stop=N_EVENTS)
_, _, reco_debug = load_eval_data_from_h5('/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_apr15_debug_true_mask_compare_truthmask_n1000.h5',
                                           event_start=0, event_stop=N_EVENTS)

data_baseline = pflow_data_from_eval_dicts(reco_baseline)
data_debug = pflow_data_from_eval_dicts(reco_debug)

# %%
figs_compare = run_reco_analysis(
    data_baseline,
    compare_data=data_debug,
    compare_label="True-pileup-mask-reconstruction",
    )
# Out:
# Calo mask purity…
#   reco_analysis/calo_mask_hs_energy_purity           0.44s
# Particle-level plots…
#   reco_analysis/class_distribution                   0.05s
#   reco_analysis/n_particles                          0.04s
#   reco_analysis/n_particles_by_pt_bin                0.29s
#   reco_analysis/feature_distributions                0.55s
#   reco_analysis/feature_scatter                      2.05s
#   reco_analysis/ptetaphi_residuals                   0.83s
#   reco_analysis/pt_residual_absolute                 0.29s
#   reco_analysis/extra_particles_pt1to2               0.38s
#   reco_analysis/pileup_token_incidence_value_hist    0.17s
#   reco_analysis/incidence_heatmap                    0.06s
#   reco_analysis/incidence_diff                       0.05s
#   reco_analysis/incidence_track_match                0.08s
# Clustering jets…
# Jets (pflow): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1448.99it/s]
# Jets (truth): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1790.29it/s]
# Clustering compare jets…
# Jets (pflow): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2014.89it/s]
# Jets (truth): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1834.21it/s]
#   reco_analysis/jet_multiplicity                     0.04s
# Jet resolution…
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 27902.87it/s]
#   reco_analysis/jet_resolution                       0.42s
# Jets (calo): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:16<00:00, 59.98it/s]
# Jets (calo-hs): 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 811.52it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 27784.58it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 28176.17it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 25505.51it/s]
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 28610.73it/s]
#   reco_analysis/jet_resolution_with_calo             18.76s
# Matching jets: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 27860.98it/s]
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/reco_analysis.py:2447: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   ax.text(0.5, 0.5, "no matched jets in pt bin", ha="center", va="center", transform=ax.transAxes)
#   reco_analysis/jet_resolution_truth_pt_* (5 bins) 0.94s
#   reco_analysis/event_display_0                      0.05s
#   reco_analysis/event_split_0                        0.08s
# Done — 23 plots generated.

# %%
plot_calo_mask_energy_purity()

# %%
from hepattn.experiments.odd_pileup_reco.reco_analysis import run_fp_neu_hadron_analysis, pflow_data_from_eval_dicts

# Reuse already prepared analysis dict when available
if "data_baseline" in globals():
    fp_data = data_baseline
elif "reco_baseline" in globals():
    fp_data = pflow_data_from_eval_dicts(reco_baseline)
else:
    fp_data = pflow_data_from_eval_dicts(reco_data)

fp_neuhad_figs = run_fp_neu_hadron_analysis(
    fp_data,
    ind_threshold=0.5,
    incidence_threshold=1e-3,
    neu_had_class=3,
)

display(fp_neuhad_figs["reco_analysis_fp_neuhad/fp_neuhad_diagnostics"])
display(fp_neuhad_figs["reco_analysis_fp_neuhad/fp_neuhad_node_source"])
# Out:
# FP Neu Had focused plots…
#   reco_analysis_fp_neuhad/fp_neuhad_diagnostics      0.49s
#   reco_analysis_fp_neuhad/fp_neuhad_node_source      0.86s
# Done — 2 FP Neu Had plots generated.

# %%
from hepattn.experiments.odd_pileup_reco.reco_analysis import (
    run_zero_bin_analysis,
    pflow_data_from_eval_dicts,
)

# Prefer already-converted baseline analysis data when available
if "data_baseline" in globals():
    zero_data = data_baseline
elif "reco_baseline" in globals():
    zero_data = pflow_data_from_eval_dicts(reco_baseline)
else:
    zero_data = pflow_data_from_eval_dicts(reco_data)

zero_figs = run_zero_bin_analysis(
    zero_data,
    ind_threshold=0.5,
    eta_zero_width=0.05,
    phi_zero_width=0.05,
)

display(zero_figs["reco_analysis_zero_bin/zero_bin_diagnostics"])
display(zero_figs["reco_analysis_zero_bin/class_hist_all_events"])
list(zero_figs.keys())
# Out:
# Zero-bin focused plots…
#   reco_analysis_zero_bin/zero_bin_diagnostics        0.62s
#   reco_analysis_zero_bin/class_hist_all_events       0.06s
# Done — 2 zero-bin plots generated.
# ['reco_analysis_zero_bin/zero_bin_diagnostics',
#  'reco_analysis_zero_bin/class_hist_all_events']

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import load_eval
track_data, cluster_data,reco_data,model,loader = load_eval(files=val_files, num_events=700,
                                                  ckpt_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=039-val_loss=13.28025.ckpt')
# Out:
# Loading config from /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml
# Building dataloader...
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 700 samples
# Is inference: False
# Loading Events:   0%|                                                                           | 0/700 [00:00<?, ?evt/s]
# Processing file index 686 (File 1/98)
# Loading Events:  13%|████████▎                                                         | 88/700 [00:02<00:20, 30.36evt/s]
# Processing file index 214 (File 2/98)
# Loading Events:  26%|████████████████▉                                                | 183/700 [00:05<00:15, 33.49evt/s]
# Processing file index 363 (File 3/98)
# Loading Events:  40%|█████████████████████████▊                                       | 278/700 [00:07<00:11, 38.22evt/s]
# Processing file index 379 (File 4/98)
# Loading Events:  54%|██████████████████████████████████▊                              | 375/700 [00:12<00:12, 26.68evt/s]
# Processing file index 166 (File 5/98)
# Loading Events:  67%|███████████████████████████████████████████▌                     | 469/700 [00:15<00:08, 28.65evt/s]
# Processing file index 373 (File 6/98)
# Loading Events:  81%|████████████████████████████████████████████████████▍            | 565/700 [00:18<00:04, 31.54evt/s]
# Processing file index 854 (File 7/98)
# Loading Events:  94%|█████████████████████████████████████████████████████████████▎   | 660/700 [00:21<00:01, 30.39evt/s]
# Processing file index 650 (File 8/98)
# Loading Events: 100%|█████████████████████████████████████████████████████████████████| 700/700 [00:23<00:00, 29.20evt/s]
# --- Filtering Statistics ---
# Total events processed: 800
# Events dropped (Too many nodes > 5500): 45
# Events dropped (Too many particles > 399): 0
# Total events kept: 700
# ----------------------------
# Loaded 700 events. Concatenating arrays...
# event numbers 10: [68600 68601 68602 68604 68605 68606 68607 68608 68609 68610]
# Number of events after filtering: 700
# Track composition: Hard scatter 35971 (5.8%) | Pileup 586160 (94.2%)
# Energy composition: Total deposited HS energy 5.55e+05 | Total cluster energy 1.52e+07 | Ratio 0.0365
# --- Delta R window analysis (100 sampled events, window_size=256) ---
# Avg nodes per event: 4914
# Mean delta R within window: 0.8987  [Q1=0.8837, Q3=0.9091]
# Mean max delta R within window: 4.4862  [Q1=4.4694, Q3=4.5031]
# -------------------------------------------------------------------------
# Dataset: 700 events from 98 file(s)
#   15 batches
# Loading model from /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=039-val_loss=13.28025.ckpt
# Running inference...
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# [DBG logit] key=reco_pflow_node_logit shape=(48, 400, 1400)
# [DBG logit] min=-101.50 max=26.75 mean=-49.35
# [DBG logit] isinf=0 isnan=0
# [DBG logit row0] min=-100.00 max=24.00
# [DBG target] key=reco_particle_node_valid shape=(48, 400, 1400)
# [DBG target] min=0.0000 max=1.0000 sum=84465.0
# [DBG target] >1: 0  <0: 0
# [DBG target row0] sum=61384.0 max=1.0000
# [DBG node_valid] valid_per_sample: min=273 max=1297 mean=804.5
# [DBG node_valid] any_zero_rows=False
# Using Hungarian matching for reco eval pairing.
#   Batch 10 done
#   Tracks: 622131 nodes
#   Clusters: 2858589 nodes
#   Reco objects: 280000 slots

# %%
import importlib
import hepattn.experiments.odd_pileup_reco.eval_data as eval_data
import hepattn.experiments.odd_pileup_reco.eval_plots as eval_plots

importlib.reload(eval_data)
importlib.reload(eval_plots)
load_eval_data_from_h5 = eval_data.load_eval_data_from_h5
plot_incidence_matrix_event = eval_plots.plot_incidence_matrix_event

# Reload reco_data if this notebook variable is stale and missing new reco-node metadata.
if "reco_is_track" not in reco_data or "reco_node_valid" not in reco_data:
    _, _, reco_data = load_eval_data_from_h5(
        '/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=042-val_loss=13.01940__test.h5',
        event_indices=range(10),
    )

# 1) Legacy pileup-focused view (1400 reco nodes).
fig_incidence, inc_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="pileup",
    num_nodes=1400,
 )

# 2) Pred-vs-truth binary overlap view (match / false positive / missed).
# tracks_only + pred_track_proxy + exclude_pileup_row matches old non-pileup logic better.
fig_cmp_bin, cmp_bin_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="binary_compare",
    truth_key="truth_incidence",
    num_nodes=1400,
    max_objects=130,
    pred_threshold=0.0,
    truth_threshold=0.0,
    tracks_only=True,
    pred_track_proxy=True,
    exclude_pileup_row=True,
 )

# 3) Raw side-by-side incidence maps in reco-node space (with valid masking).
fig_cmp_raw, cmp_raw_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="raw_compare",
    truth_key="truth_incidence",
    num_nodes=1400,
    max_objects=130,
 )

fig_cmp_bin
cmp_bin_stats
cmp_raw_stats
# Out:
# {'event_index': 0,
#  'matrix_shape': (130, 1400),
#  'pred_sum': 717.7977294921875,
#  'truth_sum': 1395.6014404296875,
#  'pred_nan_count': 0,
#  'truth_nan_count': 0,
#  'tracks_only': 0,
#  'exclude_pileup_row': 0,
#  'n_tracks': 707,
#  'n_valid_nodes': 1400,
#  'n_valid_truth_objects': 130}

# %%
reco_data.keys()
# Out:
# dict_keys(['pred_class', 'pred_valid', 'truth_class', 'truth_valid', 'pred_pt', 'truth_pt', 'pred_eta', 'truth_eta', 'pred_sinphi', 'truth_sinphi', 'pred_cosphi', 'truth_cosphi'])

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import make_plots
figs = make_plots(track_data, cluster_data,reco_data=reco_data)
# Out:
#   calo/neutral_energy_frac                 0.31s
#   calo/charged_energy_frac                 0.30s
#   calo/cluster_energy_dist                 0.28s
#   calo/mask_energy_ratio                   0.49s
#   calo/hs_energy_residual_by_type          0.09s
#   calo/hs_energy_ratio_by_type             0.10s
#   calo/mask_f1_vs_threshold                8.20s
#   calo/mask_f1_recall_neutral_clusters     0.68s
#   calo/mask_f1_recall_charged_clusters     0.67s
#   calo/mask_errors_by_energy               skipped (pred_frac unavailable)
#   calo/mistag_eta                          0.94s
#   calo/mask_metrics_vs_eta                 2.71s
#   calo/mask_metrics_vs_phi                 2.94s
#   calo/mask_metrics_vs_energy              2.84s
#   track/score_dist                         0.14s
#   track/eff_vs_pt                          0.17s
#   track/f1_vs_pt                           0.54s
#   track/rej_vs_pt                          0.21s
#   track/mistag_eta                         0.19s
#   track/score_by_pt                        0.11s
#   track/f1_vs_threshold                    1.01s
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_maskformer/plots.py:1099: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(6, 6))
#   track/roc                                0.32s
#   track/z0_dist                            0.43s
#   track/pt_dist                            0.10s

# %%
import torch

inputs_b, targets_b = next(iter(loader))
print("Target keys:", sorted(targets_b.keys()))
for k in sorted(targets_b.keys()):
    v = targets_b[k]
    if isinstance(v, torch.Tensor):
        print(f"{k:35s} shape={tuple(v.shape)} dtype={v.dtype}")
# Out:
# Target keys: ['calo_hard_scatter_energy', 'calo_hard_scatter_energy_frac', 'calo_hs_charged_energy', 'calo_hs_neutral_energy', 'event_number', 'is_track', 'node_e', 'node_eta', 'node_is_track', 'node_phi', 'node_pt', 'node_valid', 'node_z0', 'particle_node_valid', 'particle_valid', 'particle_vz', 'tracks_mask']
# calo_hard_scatter_energy            shape=(48, 5500) dtype=torch.float32
# calo_hard_scatter_energy_frac       shape=(48, 5500) dtype=torch.float32
# calo_hs_charged_energy              shape=(48, 5500) dtype=torch.float32
# calo_hs_neutral_energy              shape=(48, 5500) dtype=torch.float32
# event_number                        shape=(48,) dtype=torch.int64
# is_track                            shape=(48, 5500) dtype=torch.float32
# node_e                              shape=(48, 5500) dtype=torch.float32
# node_eta                            shape=(48, 5500) dtype=torch.float32
# node_is_track                       shape=(48, 5500) dtype=torch.float32
# node_phi                            shape=(48, 5500) dtype=torch.float32
# node_pt                             shape=(48, 5500) dtype=torch.float32
# node_valid                          shape=(48, 5500) dtype=torch.bool
# node_z0                             shape=(48, 5500) dtype=torch.float32
# particle_node_valid                 shape=(48, 1, 5500) dtype=torch.float32
# particle_valid                      shape=(48, 1) dtype=torch.bool
# particle_vz                         shape=(48, 1) dtype=torch.float32
# tracks_mask                         shape=(48, 5500) dtype=torch.float32
