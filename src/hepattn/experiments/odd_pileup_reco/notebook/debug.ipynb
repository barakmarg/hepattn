# %%
# %load_ext autoreload
# %autoreload 2

# %%
val_files = [    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00686.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00214.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00363.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00379.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00166.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00373.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00854.parquet',]

# %%
val_files=[
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00686.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00214.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00363.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00379.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00166.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00373.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00854.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00650.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00464.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00927.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00920.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00103.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00951.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00875.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00081.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00296.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00791.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00233.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00677.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00046.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00071.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00721.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00196.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00591.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00370.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00882.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00633.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00643.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00849.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00300.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00565.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00080.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00387.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00127.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00549.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00470.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00747.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00044.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00826.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00270.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00618.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00352.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00867.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00367.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00099.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00389.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00094.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00963.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00344.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00781.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00220.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00159.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00937.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00348.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00956.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00714.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00163.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00825.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00777.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00006.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00890.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00828.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00284.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00603.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00459.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00225.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00429.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00959.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00718.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00665.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00733.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00203.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00574.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00027.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00616.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00517.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00238.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00223.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00095.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00030.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00032.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00432.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00604.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00089.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00558.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00913.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00758.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00692.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00104.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00754.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00142.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00228.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00250.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00281.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00759.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00025.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00114.parquet',
    '/storage/agrp/barakma/PileupODD/data/ttbar_pu200/target_particles-00654.parquet'
]

# %%
from hepattn.experiments.odd_pileup_reco.eval_data import  run_forward_pass        
hp_path = run_forward_pass(ckpt_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560.ckpt',
                           config_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml',
                           files=val_files,
                           num_events=1000,
                           batch_size=64,
                           test_suff='update_no_track_filter',
                           inference_mode=False,
                           )
# Out:
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# Using bfloat16 Automatic Mixed Precision (AMP)
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Running test...
# ----------------------------------------------------------------------------------------------------
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 1000 samples
# Is inference: True
# Processing file index 686 (File 1/98)
# Processing file index 214 (File 2/98)
# Processing file index 363 (File 3/98)
# Processing file index 379 (File 4/98)
# Processing file index 166 (File 5/98)
# Processing file index 373 (File 6/98)
# Processing file index 854 (File 7/98)
# Processing file index 650 (File 8/98)
# Processing file index 464 (File 9/98)
# Processing file index 927 (File 10/98)
# Processing file index 920 (File 11/98)
# Loading Events: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:40<00:00, 24.98evt/s]
# --- Filtering Statistics ---
# Total events processed: 1100
# Events dropped (Too many nodes > 5500): 77
# Events dropped (Too many particles > 399): 0
# Total events kept: 1000
# ----------------------------
# Loaded 1000 events. Concatenating arrays...
# event numbers 10: [68600 68601 68602 68604 68605 68606 68607 68608 68609 68610]
# Number of events after filtering: 1000
# Track composition: Hard scatter 52828 (5.9%) | Pileup 839482 (94.1%)
# Energy composition: Total deposited HS energy 8.06e+05 | Total cluster energy 2.17e+07 | Ratio 0.0372
# --- Delta R window analysis (100 sampled events, window_size=256) ---
# Avg nodes per event: 4939
# Mean delta R within window: 0.8968  [Q1=0.8813, Q3=0.9112]
# Mean max delta R within window: 4.4889  [Q1=4.4742, Q3=4.5063]
# -------------------------------------------------------------------------
# Restoring states from the checkpoint path at /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560.ckpt
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:282: Be aware that when using `ckpt_path`, callbacks used to create the checkpoint need to be provided during `Trainer` instantiation. Please add the following callbacks: ["Checkpoint{'monitor': 'val/loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}"].
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [GPU-4d959956-42fe-6e1e-227a-5d35b01b0a40]
# Loaded model weights from the checkpoint at /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560.ckpt
# Created test dataset with 1,000 events
# ----------------------------------------------------------------------------------------------------
#
# Instantiating test dataloader on rank 0
# Creating test dataloader with 1,000 events
# Instantiating test dataloader on rank 0
# Creating test dataloader with 1,000 events
# Testing: |                                                                                                    …
# [DBG logit] key=reco_pflow_node_logit shape=(64, 400, 1400)
# [DBG logit] min=-101.00 max=33.75 mean=-49.14
# [DBG logit] isinf=0 isnan=0
# [DBG logit row0] min=-100.00 max=29.88
# [DBG target] key=reco_particle_node_valid shape=(64, 400, 1400)
# [DBG target] min=0.0000 max=1.0000 sum=76288.0
# [DBG target] >1: 0  <0: 0
# [DBG target row0] sum=45248.0 max=1.0000
# [DBG node_valid] valid_per_sample: min=278 max=1312 mean=805.4
# [DBG node_valid] any_zero_rows=False
# Wrote predictions to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_update_no_track_filter.h5
# Loading predictions...
# Writing to ROOT file
# Wrote ROOT file to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_update_no_track_filter.root
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                Test metric                 ┃                DataLoader 0                ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test/calo_final_calo_mask_mask_bce     │             0.2992109954357147             │
# │   test/calo_final_calo_mask_mask_tversky   │             1.7952665090560913             │
# │            test/calo_final_loss            │             2.0944771766662598             │
# │             test/calo_mask_f1              │            0.43304115533828735             │
# │          test/calo_mask_precision          │            0.29558059573173523             │
# │           test/calo_mask_recall            │             0.8095025420188904             │
# │                 test/loss                  │             29.395061492919922             │
# │               test/reco_eff                │             0.7616486549377441             │
# │  test/reco_final_classification_object_ce  │             3.9048666954040527             │
# │      test/reco_final_incidence_kl_div      │           0.0054489620961248875            │
# │            test/reco_final_loss            │             4.843014240264893              │
# │       test/reco_final_mask_mask_bce        │            0.08415914326906204             │
# │       test/reco_final_mask_mask_dice       │            0.44116994738578796             │
# │       test/reco_final_regression_l1        │             0.4073692560195923             │
# │ test/reco_layer_0_classification_object_ce │             2.7194108963012695             │
# │           test/reco_layer_0_loss           │             3.286701202392578              │
# │      test/reco_layer_0_mask_mask_bce       │            0.09365712106227875             │
# │      test/reco_layer_0_mask_mask_dice      │            0.47363319993019104             │
# │ test/reco_layer_1_classification_object_ce │             4.849158763885498              │
# │           test/reco_layer_1_loss           │             5.391133785247803              │
# │      test/reco_layer_1_mask_mask_bce       │            0.08918611705303192             │
# │      test/reco_layer_1_mask_mask_dice      │             0.4527895450592041             │
# │ test/reco_layer_2_classification_object_ce │             5.638720512390137              │
# │           test/reco_layer_2_loss           │             6.1594743728637695             │
# │      test/reco_layer_2_mask_mask_bce       │            0.08643857389688492             │
# │      test/reco_layer_2_mask_mask_dice      │            0.43431544303894043             │
# │ test/reco_layer_3_classification_object_ce │             5.916311264038086              │
# │           test/reco_layer_3_loss           │              6.42471170425415              │
# │      test/reco_layer_3_mask_mask_bce       │            0.08652466535568237             │
# │      test/reco_layer_3_mask_mask_dice      │             0.421875923871994              │
# │           test/reco_mask_purity            │             0.4328159987926483             │
# │           test/reco_mask_recall            │             0.4181700348854065             │
# │     test/reco_obj_class_accuracy_macro     │             0.5864001512527466             │
# │     test/reco_obj_class_accuracy_micro     │             0.6783549785614014             │
# │               test/reco_pur                │             0.6135339140892029             │
# │               test/track_f1                │             0.8755967617034912             │
# │           test/track_final_loss            │             0.2284523993730545             │
# │       test/track_final_mask_mask_bce       │            0.03649599850177765             │
# │      test/track_final_mask_mask_dice       │            0.13260143995285034             │
# │  test/track_final_vz_regression_smooth_l1  │            0.059354960918426514            │
# │          test/track_layer_0_loss           │             0.3857247829437256             │
# │      test/track_layer_0_mask_mask_bce      │            0.08953532576560974             │
# │     test/track_layer_0_mask_mask_dice      │            0.29618948698043823             │
# │          test/track_layer_1_loss           │            0.22723864018917084             │
# │      test/track_layer_1_mask_mask_bce      │             0.043378796428442              │
# │     test/track_layer_1_mask_mask_dice      │            0.18385984003543854             │
# │          test/track_layer_2_loss           │            0.18306483328342438             │
# │      test/track_layer_2_mask_mask_bce      │            0.037754327058792114            │
# │     test/track_layer_2_mask_mask_dice      │            0.14531050622463226             │
# │          test/track_layer_3_loss           │            0.17106838524341583             │
# │      test/track_layer_3_mask_mask_bce      │            0.03686196729540825             │
# │     test/track_layer_3_mask_mask_dice      │            0.13420641422271729             │
# │            test/track_precision            │             0.8745962977409363             │
# │             test/track_recall              │             0.8765995502471924             │
# │                test/vz_mae                 │             5.408670425415039              │
# └────────────────────────────────────────────┴────────────────────────────────────────────┘
# Predictions written to /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test_update_no_track_filter.h5

# %%
! export IOTHROTTLE_LIMIT=100

# %%
from hepattn.experiments.odd_pileup_reco.eval_data import load_eval_data_from_h5
track_data, cluster_data, reco_data = load_eval_data_from_h5('/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260412-T163313/ckpts/epoch=028-val_loss=10.78560__test.h5',
                                                             event_indices=range(1000))

# %%
import numpy as np
import torch
threshold = 1e-5    
event_index = 0
e = event_index
from hepattn.experiments.odd_pileup_reco.reco_analysis import select_charged_tracks
truth_full = np.asarray(reco_data["truth_incidence"][e], dtype=np.float32)   # (P, 5500)
pred_filt = np.asarray(reco_data["pred_incidence"][e], dtype=np.float32)     # (P, 1400)
reco_idx = np.asarray(reco_data["reco_node_indices"][e], dtype=np.int64)     # (1400,)
track_mask = np.asarray(reco_data["reco_is_track"][e]).astype(bool).reshape(-1)

# Map truth to filtered reco-node space
truth_filt = np.take(truth_full, reco_idx, axis=1)                             # (P, 1400)

# Raw row-0 diagnostics before enforcing constraints
row0_truth_track = truth_filt[0, track_mask]
row0_pred_track = pred_filt[0, track_mask]

print("=" * 72)
print("RAW DIAGNOSTICS")
print("=" * 72)
print("event:", e)
print("track columns:", int(track_mask.sum()))
print("truth row0 > 0.3 on track cols:", int(np.count_nonzero(row0_truth_track > 0.3)))
print("pred  row0 > 0.3 on track cols:", int(np.count_nonzero(row0_pred_track > 0.3)))
print("truth row0 max on track cols:", float(row0_truth_track.max()) if row0_truth_track.size else 0.0)
print("pred  row0 max on track cols:", float(row0_pred_track.max()) if row0_pred_track.size else 0.0)

# Enforce intended semantics for comparison:
# 1) threshold tiny values
# 2) force row0(track cols)=0
# 3) one-track-per-particle via select_charged_tracks
pred_proc = pred_filt.copy()
truth_proc = truth_filt.copy()

pred_proc[pred_proc <= threshold] = 0.0
truth_proc[truth_proc <= threshold] = 0.0

pred_proc[0, track_mask] = 0.0
truth_proc[0, track_mask] = 0.0

pred_sel = select_charged_tracks(
    torch.from_numpy(pred_proc).unsqueeze(0),
    torch.from_numpy(track_mask).unsqueeze(0),
).squeeze(0).cpu().numpy() > 0

truth_sel = select_charged_tracks(
    torch.from_numpy(truth_proc).unsqueeze(0),
    torch.from_numpy(track_mask).unsqueeze(0),
).squeeze(0).cpu().numpy() > 0

pred_tracks_per_particle = pred_sel[:, track_mask].sum(axis=1)
truth_tracks_per_particle = truth_sel[:, track_mask].sum(axis=1)

print("\n" + "=" * 72)
print("AFTER ENFORCING ROW0-TRACK=0 + ONE-TRACK SELECTION")
print("=" * 72)
print("pred max tracks/particle :", int(pred_tracks_per_particle.max()) if pred_tracks_per_particle.size else 0)
print("truth max tracks/particle:", int(truth_tracks_per_particle.max()) if truth_tracks_per_particle.size else 0)
print("pred particles with >1 track :", int(np.sum(pred_tracks_per_particle > 1)))
print("truth particles with >1 track:", int(np.sum(truth_tracks_per_particle > 1)))
print("row0 pred selected tracks  :", int(pred_tracks_per_particle[0]))
print("row0 truth selected tracks :", int(truth_tracks_per_particle[0]))

# Optional binary match stats excluding pileup row
pred_bin = pred_sel[1:, track_mask]
truth_bin = truth_sel[1:, track_mask]

matches = pred_bin & truth_bin
fp = pred_bin & (~truth_bin)
fn = truth_bin & (~pred_bin)

n_match = int(np.count_nonzero(matches))
n_fp = int(np.count_nonzero(fp))
n_fn = int(np.count_nonzero(fn))
n_truth = int(np.count_nonzero(truth_bin))
n_pred = int(np.count_nonzero(pred_bin))

recall = (100.0 * n_match / n_truth) if n_truth > 0 else 0.0
precision = (100.0 * n_match / n_pred) if n_pred > 0 else 0.0

print("\n" + "=" * 72)
print("MATCH STATS (EXCLUDING PILEUP ROW)")
print("=" * 72)
print("matches:", n_match, "fp:", n_fp, "fn:", n_fn)
print(f"recall={recall:.2f}%  precision={precision:.2f}%")
# Out:
# ========================================================================
# RAW DIAGNOSTICS
# ========================================================================
# event: 0
# track columns: 779
# truth row0 > 0.3 on track cols: 0
# pred  row0 > 0.3 on track cols: 0
# truth row0 max on track cols: 0.0
# pred  row0 max on track cols: 4.235256346873939e-05
#
# ========================================================================
# AFTER ENFORCING ROW0-TRACK=0 + ONE-TRACK SELECTION
# ========================================================================
# pred max tracks/particle : 1
# truth max tracks/particle: 1
# pred particles with >1 track : 0
# truth particles with >1 track: 0
# row0 pred selected tracks  : 0
# row0 truth selected tracks : 0
#
# ========================================================================
# MATCH STATS (EXCLUDING PILEUP ROW)
# ========================================================================
# matches: 43 fp: 23 fn: 21
# recall=67.19%  precision=65.15%

# %%
from hepattn.experiments.odd_pileup_reco.reco_analysis import run_reco_analysis, pflow_data_from_eval_dicts
figs = run_reco_analysis(pflow_data_from_eval_dicts(reco_data))
figs["reco_analysis/extra_particles_pt1to2"]
figs["reco_analysis/pileup_token_incidence_value_hist"]
# Out:
# Particle-level plots…
#   reco_analysis/class_distribution                   0.03s
#   reco_analysis/n_particles                          0.03s
#   reco_analysis/n_particles_by_pt_bin                0.18s
#   reco_analysis/feature_distributions                0.35s
#   reco_analysis/feature_scatter                      0.24s
#   reco_analysis/ptetaphi_residuals                   0.53s
#   reco_analysis/pt_residual_absolute                 0.19s
#   reco_analysis/extra_particles_pt1to2               0.20s
#   reco_analysis/pileup_token_incidence_value_hist    0.11s
#   reco_analysis/incidence_heatmap                    0.04s
#   reco_analysis/incidence_diff                       0.03s
#   reco_analysis/incidence_track_match                0.05s
# Clustering jets…
# Jets (pflow): 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2289.51it/s]
# Jets (truth): 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 2921.83it/s]
#   reco_analysis/jet_multiplicity                     0.03s
# Jet resolution…
# Matching jets: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 58845.13it/s]
#   reco_analysis/jet_resolution                       0.12s
#   reco_analysis/event_display_0                      0.03s
#   reco_analysis/event_split_0                        0.06s
# Done — 16 plots generated.

# %%
from hepattn.experiments.odd_pileup_two_stream.eval_plots import build_dataloader, load_config, load_config
cfg = load_config(config_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml')
loader = build_dataloader(cfg, files=val_files, num_events=4000)
# Out:
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 4000 samples
# Is inference: False
# Loading Events:   0%|                                                                          | 0/4000 [00:00<?, ?evt/s]
# Processing file index 686 (File 1/98)
# Loading Events:   2%|█▍                                                               | 88/4000 [00:03<02:28, 26.34evt/s]
# Processing file index 214 (File 2/98)
# Loading Events:   5%|██▉                                                             | 183/4000 [00:06<02:02, 31.12evt/s]
# Processing file index 363 (File 3/98)
# Loading Events:   7%|████▍                                                           | 278/4000 [00:07<01:34, 39.27evt/s]
# Processing file index 379 (File 4/98)
# Loading Events:   9%|██████                                                          | 375/4000 [00:11<01:49, 33.03evt/s]
# Processing file index 166 (File 5/98)
# Loading Events:  12%|███████▌                                                        | 469/4000 [00:13<01:44, 33.92evt/s]
# Processing file index 373 (File 6/98)
# Loading Events:  14%|█████████                                                       | 565/4000 [00:16<01:32, 36.98evt/s]
# Processing file index 854 (File 7/98)
# Loading Events:  16%|██████████▌                                                     | 660/4000 [00:18<01:32, 36.06evt/s]
# Processing file index 650 (File 8/98)
# Loading Events:  19%|████████████                                                    | 755/4000 [00:20<01:18, 41.35evt/s]
# Processing file index 464 (File 9/98)
# Loading Events:  21%|█████████████▌                                                  | 848/4000 [00:22<01:09, 45.65evt/s]
# Processing file index 927 (File 10/98)
# Loading Events:  23%|███████████████                                                 | 938/4000 [00:24<01:17, 39.75evt/s]
# Processing file index 920 (File 11/98)
# Loading Events:  26%|████████████████▎                                              | 1032/4000 [00:27<01:11, 41.47evt/s]
# Processing file index 103 (File 12/98)
# Loading Events:  28%|█████████████████▊                                             | 1132/4000 [00:31<01:32, 31.08evt/s]
# Processing file index 951 (File 13/98)
# Loading Events:  31%|███████████████████▎                                           | 1226/4000 [00:35<01:32, 29.98evt/s]
# Processing file index 875 (File 14/98)
# Loading Events:  33%|████████████████████▊                                          | 1318/4000 [00:37<01:24, 31.57evt/s]
# Processing file index 81 (File 15/98)
# Loading Events:  35%|██████████████████████▏                                        | 1409/4000 [00:40<01:20, 32.18evt/s]
# Processing file index 296 (File 16/98)
# Loading Events:  38%|███████████████████████▋                                       | 1504/4000 [00:42<01:11, 34.74evt/s]
# Processing file index 791 (File 17/98)
# Loading Events:  40%|█████████████████████████▏                                     | 1596/4000 [00:45<01:06, 36.00evt/s]
# Processing file index 233 (File 18/98)
# Loading Events:  42%|██████████████████████████▋                                    | 1694/4000 [00:47<01:01, 37.26evt/s]
# Processing file index 677 (File 19/98)
# Loading Events:  45%|████████████████████████████▏                                  | 1788/4000 [00:51<01:10, 31.19evt/s]
# Processing file index 46 (File 20/98)
# Loading Events:  47%|█████████████████████████████▋                                 | 1883/4000 [00:56<01:15, 27.94evt/s]
# Processing file index 71 (File 21/98)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[3], line 3
#       2 cfg = load_config(config_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml')
# ----> 3 loader = build_dataloader(cfg, files=val_files, num_events=4000)
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_two_stream/eval_plots.py:169, in build_dataloader(cfg, files, data_dir, num_events, batch_size, num_workers)
#     167     raise ValueError("Provide either `files` (list of parquet paths) or `data_dir`.")
# --> 169 dataset = ODDDatasetPileup(
#     170     filepath=filepath,
#     171     inputs=data_cfg["inputs"],
#     172     targets=data_cfg["targets"],
#     173     scale_dict_path=data_cfg["scale_dict_path"],
#     174     num_events=num_events,
#     175     max_nodes=data_cfg["max_nodes"],
#     176     incidence_cutval=data_cfg.get("incidence_cutval", 0.01),
#     177     hard_scatter_energy_threshold=data_cfg.get("hard_scatter_energy_threshold", 0.03),
#     178     window_size=data_cfg.get("window_size", 512),
#     179     files_list=files_list,
#     180     is_inference=False,
#     181 )
#     182 print(f"Dataset: {len(dataset)} events from {len(files_list) if files_list else 'dir'} file(s)")
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_maskformer/pflow_data.py:137, in ODDDatasetPileup.__init__(self, filepath, inputs, targets, scale_dict_path, num_events, max_nodes, remove_wrong_idxs, incidence_cutval, is_inference, files_list, hard_scatter_energy_threshold, window_size)
#     136 # Load data from parquet
# --> 137 self.load_data(filepath,num_events)
#     138 gc.collect()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_maskformer/pflow_data.py:215, in ODDDatasetPileup.load_data(self, file_dir, num_events)
#     213 # If we're not in test stage, allow a user hook to run here.
# --> 215 df_particles, df_clusters, df_deps, df_tracks = self.preprocess_hook(file_dir_path, idx)
#     217 # B. Filter (Locally)
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_maskformer/pflow_data.py:708, in ODDDatasetPileup.preprocess_hook(self, file_dir, index)
#     707 df_clusters = pl.read_parquet(file_dir / f"calo_clusters-{index:05d}.parquet")
# --> 708 df_deps = pl.read_parquet(file_dir / f"target_particles_deps-{index:05d}.parquet")
#     709 df_tracks = pl.read_parquet(file_dir / f"tracks-{index:05d}.parquet")
#
# File ~/.local/lib/python3.11/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     125 _rename_keyword_argument(
#     126     old_name, new_name, kwargs, function.__qualname__, version
#     127 )
# --> 128 return function(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/polars/_utils/deprecation.py:128, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     125 _rename_keyword_argument(
#     126     old_name, new_name, kwargs, function.__qualname__, version
#     127 )
# --> 128 return function(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/polars/io/parquet/functions.py:289, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, missing_columns, allow_missing_columns)
#     287         lf = lf.select(columns)
# --> 289 return lf.collect()
#
# File ~/.local/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:328, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 kwargs["optimizations"] = optflags
# --> 328 return function(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/polars/lazyframe/frame.py:2422, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2421 callback = _kwargs.get("post_opt_callback", callback)
# -> 2422 return wrap_df(ldf.collect(engine, callback))
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3598, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3596 except:
#    3597     if result is not None:
# -> 3598         result.error_in_exec = sys.exc_info()[1]
#    3599     self.showtraceback(running_compiled_code=True)
#    3600 else:
#
# KeyboardInterrupt:
# Loading Events:  47%|█████████████████████████████▋                                 | 1883/4000 [01:09<01:15, 27.94evt/s]

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import make_data_plots
make_data_plots(loader)
# Out:
#   data/deltaR_window_analysis              0.03s
#   data/eta_window_analysis                 0.03s
#   data/phi_window_analysis                 0.03s
#   data/mask_hs_energy_efficiency           0.05s
# {'data/deltaR_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/eta_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/phi_window_analysis': <Figure size 800x500 with 1 Axes>,
#  'data/mask_hs_energy_efficiency': <Figure size 800x500 with 1 Axes>}

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import load_eval
track_data, cluster_data,reco_data,model,loader = load_eval(files=val_files, num_events=700,
                                                  ckpt_path='/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=039-val_loss=13.28025.ckpt')
# Out:
# Loading config from /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/configs/base.yaml
# Building dataloader...
# Loading ODD dataset from /storage/agrp/barakma/PileupODD/data/ttbar_pu200 with 700 samples
# Is inference: False
# Loading Events:   0%|                                                                           | 0/700 [00:00<?, ?evt/s]
# Processing file index 686 (File 1/98)
# Loading Events:  13%|████████▎                                                         | 88/700 [00:02<00:20, 30.36evt/s]
# Processing file index 214 (File 2/98)
# Loading Events:  26%|████████████████▉                                                | 183/700 [00:05<00:15, 33.49evt/s]
# Processing file index 363 (File 3/98)
# Loading Events:  40%|█████████████████████████▊                                       | 278/700 [00:07<00:11, 38.22evt/s]
# Processing file index 379 (File 4/98)
# Loading Events:  54%|██████████████████████████████████▊                              | 375/700 [00:12<00:12, 26.68evt/s]
# Processing file index 166 (File 5/98)
# Loading Events:  67%|███████████████████████████████████████████▌                     | 469/700 [00:15<00:08, 28.65evt/s]
# Processing file index 373 (File 6/98)
# Loading Events:  81%|████████████████████████████████████████████████████▍            | 565/700 [00:18<00:04, 31.54evt/s]
# Processing file index 854 (File 7/98)
# Loading Events:  94%|█████████████████████████████████████████████████████████████▎   | 660/700 [00:21<00:01, 30.39evt/s]
# Processing file index 650 (File 8/98)
# Loading Events: 100%|█████████████████████████████████████████████████████████████████| 700/700 [00:23<00:00, 29.20evt/s]
# --- Filtering Statistics ---
# Total events processed: 800
# Events dropped (Too many nodes > 5500): 45
# Events dropped (Too many particles > 399): 0
# Total events kept: 700
# ----------------------------
# Loaded 700 events. Concatenating arrays...
# event numbers 10: [68600 68601 68602 68604 68605 68606 68607 68608 68609 68610]
# Number of events after filtering: 700
# Track composition: Hard scatter 35971 (5.8%) | Pileup 586160 (94.2%)
# Energy composition: Total deposited HS energy 5.55e+05 | Total cluster energy 1.52e+07 | Ratio 0.0365
# --- Delta R window analysis (100 sampled events, window_size=256) ---
# Avg nodes per event: 4914
# Mean delta R within window: 0.8987  [Q1=0.8837, Q3=0.9091]
# Mean max delta R within window: 4.4862  [Q1=4.4694, Q3=4.5031]
# -------------------------------------------------------------------------
# Dataset: 700 events from 98 file(s)
#   15 batches
# Loading model from /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=039-val_loss=13.28025.ckpt
# Running inference...
# /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# [DBG logit] key=reco_pflow_node_logit shape=(48, 400, 1400)
# [DBG logit] min=-101.50 max=26.75 mean=-49.35
# [DBG logit] isinf=0 isnan=0
# [DBG logit row0] min=-100.00 max=24.00
# [DBG target] key=reco_particle_node_valid shape=(48, 400, 1400)
# [DBG target] min=0.0000 max=1.0000 sum=84465.0
# [DBG target] >1: 0  <0: 0
# [DBG target row0] sum=61384.0 max=1.0000
# [DBG node_valid] valid_per_sample: min=273 max=1297 mean=804.5
# [DBG node_valid] any_zero_rows=False
# Using Hungarian matching for reco eval pairing.
#   Batch 10 done
#   Tracks: 622131 nodes
#   Clusters: 2858589 nodes
#   Reco objects: 280000 slots

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import reco_plots
figs = reco_plots(reco_data)  
figs
# Out:
# {'reco/pt_residual_by_truth_pt': <Figure size 1800x800 with 8 Axes>,
#  'reco/eta_residual_by_truth_pt': <Figure size 1800x800 with 8 Axes>,
#  'reco/phi_residual_by_truth_pt': <Figure size 1800x800 with 8 Axes>,
#  'reco/class_pred_vs_truth_by_truth_pt': <Figure size 2000x800 with 8 Axes>,
#  'reco/class_count_residual_by_truth_pt': <Figure size 1200x500 with 2 Axes>,
#  'reco/kinematics_truth_vs_pred_all': <Figure size 1800x500 with 3 Axes>,
#  'reco/kinematics_truth_vs_pred_charged': <Figure size 1800x500 with 3 Axes>,
#  'reco/kinematics_truth_vs_pred_neutral': <Figure size 1800x500 with 3 Axes>}

# %%
import importlib
import hepattn.experiments.odd_pileup_reco.eval_data as eval_data
import hepattn.experiments.odd_pileup_reco.eval_plots as eval_plots

importlib.reload(eval_data)
importlib.reload(eval_plots)
load_eval_data_from_h5 = eval_data.load_eval_data_from_h5
plot_incidence_matrix_event = eval_plots.plot_incidence_matrix_event

# Reload reco_data if this notebook variable is stale and missing new reco-node metadata.
if "reco_is_track" not in reco_data or "reco_node_valid" not in reco_data:
    _, _, reco_data = load_eval_data_from_h5(
        '/storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/logs/odd_pflow_reco_20260405-T184853/ckpts/epoch=042-val_loss=13.01940__test.h5',
        event_indices=range(10),
    )

# 1) Legacy pileup-focused view (1400 reco nodes).
fig_incidence, inc_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="pileup",
    num_nodes=1400,
 )

# 2) Pred-vs-truth binary overlap view (match / false positive / missed).
# tracks_only + pred_track_proxy + exclude_pileup_row matches old non-pileup logic better.
fig_cmp_bin, cmp_bin_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="binary_compare",
    truth_key="truth_incidence",
    num_nodes=1400,
    max_objects=130,
    pred_threshold=0.0,
    truth_threshold=0.0,
    tracks_only=True,
    pred_track_proxy=True,
    exclude_pileup_row=True,
 )

# 3) Raw side-by-side incidence maps in reco-node space (with valid masking).
fig_cmp_raw, cmp_raw_stats = plot_incidence_matrix_event(
    reco_data,
    event_index=0,
    mode="raw_compare",
    truth_key="truth_incidence",
    num_nodes=1400,
    max_objects=130,
 )

fig_cmp_bin
cmp_bin_stats
cmp_raw_stats
# Out:
# {'event_index': 0,
#  'matrix_shape': (130, 1400),
#  'pred_sum': 717.7977294921875,
#  'truth_sum': 1395.6014404296875,
#  'pred_nan_count': 0,
#  'truth_nan_count': 0,
#  'tracks_only': 0,
#  'exclude_pileup_row': 0,
#  'n_tracks': 707,
#  'n_valid_nodes': 1400,
#  'n_valid_truth_objects': 130}

# %%
reco_data.keys()
# Out:
# dict_keys(['pred_class', 'pred_valid', 'truth_class', 'truth_valid', 'pred_pt', 'truth_pt', 'pred_eta', 'truth_eta', 'pred_sinphi', 'truth_sinphi', 'pred_cosphi', 'truth_cosphi'])

# %%
from hepattn.experiments.odd_pileup_reco.eval_plots import make_plots
figs = make_plots(track_data, cluster_data,reco_data=reco_data)
# Out:
#   calo/neutral_energy_frac                 0.31s
#   calo/charged_energy_frac                 0.30s
#   calo/cluster_energy_dist                 0.28s
#   calo/mask_energy_ratio                   0.49s
#   calo/hs_energy_residual_by_type          0.09s
#   calo/hs_energy_ratio_by_type             0.10s
#   calo/mask_f1_vs_threshold                8.20s
#   calo/mask_f1_recall_neutral_clusters     0.68s
#   calo/mask_f1_recall_charged_clusters     0.67s
#   calo/mask_errors_by_energy               skipped (pred_frac unavailable)
#   calo/mistag_eta                          0.94s
#   calo/mask_metrics_vs_eta                 2.71s
#   calo/mask_metrics_vs_phi                 2.94s
#   calo/mask_metrics_vs_energy              2.84s
#   track/score_dist                         0.14s
#   track/eff_vs_pt                          0.17s
#   track/f1_vs_pt                           0.54s
#   track/rej_vs_pt                          0.21s
#   track/mistag_eta                         0.19s
#   track/score_by_pt                        0.11s
#   track/f1_vs_threshold                    1.01s
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_maskformer/plots.py:1099: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(6, 6))
#   track/roc                                0.32s
#   track/z0_dist                            0.43s
#   track/pt_dist                            0.10s

# %%
import torch

inputs_b, targets_b = next(iter(loader))
print("Target keys:", sorted(targets_b.keys()))
for k in sorted(targets_b.keys()):
    v = targets_b[k]
    if isinstance(v, torch.Tensor):
        print(f"{k:35s} shape={tuple(v.shape)} dtype={v.dtype}")
# Out:
# Target keys: ['calo_hard_scatter_energy', 'calo_hard_scatter_energy_frac', 'calo_hs_charged_energy', 'calo_hs_neutral_energy', 'event_number', 'is_track', 'node_e', 'node_eta', 'node_is_track', 'node_phi', 'node_pt', 'node_valid', 'node_z0', 'particle_node_valid', 'particle_valid', 'particle_vz', 'tracks_mask']
# calo_hard_scatter_energy            shape=(48, 5500) dtype=torch.float32
# calo_hard_scatter_energy_frac       shape=(48, 5500) dtype=torch.float32
# calo_hs_charged_energy              shape=(48, 5500) dtype=torch.float32
# calo_hs_neutral_energy              shape=(48, 5500) dtype=torch.float32
# event_number                        shape=(48,) dtype=torch.int64
# is_track                            shape=(48, 5500) dtype=torch.float32
# node_e                              shape=(48, 5500) dtype=torch.float32
# node_eta                            shape=(48, 5500) dtype=torch.float32
# node_is_track                       shape=(48, 5500) dtype=torch.float32
# node_phi                            shape=(48, 5500) dtype=torch.float32
# node_pt                             shape=(48, 5500) dtype=torch.float32
# node_valid                          shape=(48, 5500) dtype=torch.bool
# node_z0                             shape=(48, 5500) dtype=torch.float32
# particle_node_valid                 shape=(48, 1, 5500) dtype=torch.float32
# particle_valid                      shape=(48, 1) dtype=torch.bool
# particle_vz                         shape=(48, 1) dtype=torch.float32
# tracks_mask                         shape=(48, 5500) dtype=torch.float32

# %%
import torch
import numpy as np

dev = next(model.parameters()).device
inputs_b, targets_b = next(iter(loader))
inputs_b = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in inputs_b.items()}
targets_b = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in targets_b.items()}

# A) Current eval path: predict without loss (no Hungarian permutation)
with torch.no_grad(), torch.autocast(device_type=str(dev).split(":")[0], dtype=torch.bfloat16):
    out_a = model.model(inputs_b, targets=targets_b)
    pred_a = model.model.predict(out_a)

# B) Validation path: run loss first (permutes outputs in-place), then predict
with torch.no_grad(), torch.autocast(device_type=str(dev).split(":")[0], dtype=torch.bfloat16):
    out_b = model.model(inputs_b, targets=targets_b)
    _ = model.model.loss(out_b, targets_b)
    pred_b = model.model.predict(out_b)

pt_a = pred_a["reco_final"]["regression"]["reco_pflow_pt"].detach().cpu().float()
pt_b = pred_b["reco_final"]["regression"]["reco_pflow_pt"].detach().cpu().float()
truth_valid = targets_b["reco_particle_valid"].detach().cpu().bool()

scaler = loader.dataset.scaler.transforms["pt"]
pt_a_inv = scaler.inverse_transform(pt_a.unsqueeze(-1)).squeeze(-1)
pt_b_inv = scaler.inverse_transform(pt_b.unsqueeze(-1)).squeeze(-1)

vals_a = pt_a_inv[truth_valid].numpy()
vals_b = pt_b_inv[truth_valid].numpy()

print("No-loss->predict unique rounded (0.01):", np.unique(np.round(vals_a, 2)).shape[0])
print("Loss->predict unique rounded (0.01):   ", np.unique(np.round(vals_b, 2)).shape[0])
print("No-loss->predict min/max:", float(vals_a.min()), float(vals_a.max()))
print("Loss->predict min/max:   ", float(vals_b.min()), float(vals_b.max()))
# Out:
# [DBG logit] key=reco_pflow_node_logit shape=(48, 400, 1400)
# [DBG logit] min=-101.50 max=26.75 mean=-49.35
# [DBG logit] isinf=0 isnan=0
# [DBG logit row0] min=-100.00 max=24.00
# [DBG target] key=reco_particle_node_valid shape=(48, 400, 1400)
# [DBG target] min=0.0000 max=1.0000 sum=84465.0
# [DBG target] >1: 0  <0: 0
# [DBG target row0] sum=61384.0 max=1.0000
# [DBG node_valid] valid_per_sample: min=273 max=1297 mean=804.5
# [DBG node_valid] any_zero_rows=False
# No-loss->predict unique rounded (0.01): 61
# Loss->predict unique rounded (0.01):    60
# No-loss->predict min/max: 1.0 12045648.0
# Loss->predict min/max:    1.0 12045648.0

# %%
import torch
import numpy as np

scaler = loader.dataset.scaler.transforms["pt"]

def sample_pred_pt_unique(n_batches=2, use_autocast=True):
    vals = []
    for bi, (inp, tgt) in enumerate(loader):
        if bi >= n_batches:
            break
        inp = {k: v.to(next(model.parameters()).device) if isinstance(v, torch.Tensor) else v for k, v in inp.items()}
        tgt = {k: v.to(next(model.parameters()).device) if isinstance(v, torch.Tensor) else v for k, v in tgt.items()}

        if use_autocast:
            ctx = torch.autocast(device_type="cuda", dtype=torch.bfloat16)
        else:
            ctx = torch.autocast(device_type="cuda", dtype=torch.bfloat16, enabled=False)

        with torch.no_grad(), ctx:
            out = model.model(inp, targets=tgt)
            pred = model.model.predict(out)

        pt = pred["reco_final"]["regression"]["reco_pflow_pt"].detach().cpu().float()
        tv = tgt["reco_particle_valid"].detach().cpu().bool()
        pt_inv = scaler.inverse_transform(pt.unsqueeze(-1)).squeeze(-1)
        vals.append(pt_inv[tv].numpy())

    vals = np.concatenate(vals)
    return {
        "n": int(vals.size),
        "uniq_0p01": int(np.unique(np.round(vals, 2)).shape[0]),
        "p1": float(np.percentile(vals, 1)),
        "p50": float(np.percentile(vals, 50)),
        "p99": float(np.percentile(vals, 99)),
        "max": float(np.max(vals)),
    }

print("autocast bf16:", sample_pred_pt_unique(use_autocast=True))
print("float32:     ", sample_pred_pt_unique(use_autocast=False))
# Out:
# autocast bf16: {'n': 14616, 'uniq_0p01': 105, 'p1': 1.0, 'p50': 4.834683895111084, 'p99': 48.915016174316406, 'max': 17959854.0}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[26], line 39
#      29     return {
#      30         "n": int(vals.size),
#      31         "uniq_0p01": int(np.unique(np.round(vals, 2)).shape[0]),
#    (...)
#      35         "max": float(np.max(vals)),
#      36     }
#      38 print("autocast bf16:", sample_pred_pt_unique(use_autocast=True))
# ---> 39 print("float32:     ", sample_pred_pt_unique(use_autocast=False))
#
# Cell In[26], line 20, in sample_pred_pt_unique(n_batches, use_autocast)
#      17     ctx = torch.autocast(device_type="cuda", dtype=torch.bfloat16, enabled=False)
#      19 with torch.no_grad(), ctx:
# ---> 20     out = model.model(inp, targets=tgt)
#      21     pred = model.model.predict(out)
#      23 pt = pred["reco_final"]["regression"]["reco_pflow_pt"].detach().cpu().float()
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd_pileup_reco/model.py:167, in TwoStreamMaskFormer.forward(self, inputs, targets)
#     165 # Shared encoder
#     166 if self.encoder is not None:
# --> 167     x["key_embed"] = self.encoder(x["key_embed"], x_sort_value=x.get(f"key_{self.input_sort_field}"), kv_mask=x.get("key_valid"))
#     169 # Save initial encoder output for skip connection (gradients flow back)
#     170 initial_encoder_embed = x["key_embed"]
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/models/transformer.py:288, in Encoder.forward(self, x, x_sort_value, n_global_tokens, **kwargs)
#     286 initial_values = {} if self.value_residual else None
#     287 for layer in self.layers:
# --> 288     x = layer(x, attn_mask=attn_mask, score_mod=self.score_mod, initial_values=initial_values, **kwargs)
#     290 # Remove wrapping for flash attention with sliding window
#     291 if self.attn_type == "flash" and self.window_wrap:
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/models/transformer.py:151, in EncoderLayer.forward(self, x, **kwargs)
#     150 def forward(self, x: Tensor, **kwargs) -> Tensor:
# --> 151     return self.dense(self.attn(x, **kwargs))
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/models/transformer.py:90, in Residual.forward(self, x, **kwargs)
#      88     x = self.norm(x)
#      89     return x + self.dp(self.ls(self.fn(x, **kwargs)))
# ---> 90 return x + self.dp(self.ls(self.fn(self.norm(x), **kwargs)))
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /storage/agrp/barakma/hepattn/src/hepattn/models/attention.py:354, in Attention.forward(self, q, kv, q_mask, kv_mask, attn_mask, attn_bias, score_mod, initial_values, **kwargs)
#     352     if varlen_kwargs is None:
#     353         raise ValueError("flash-varlen attention requires varlen_kwargs in kwargs")
# --> 354     out = self._flash_varlen_attention(q, k, v, **varlen_kwargs)
#     355     return self.out_proj(out)
#     357 # Fused attention
#
# File /storage/agrp/barakma/hepattn/src/hepattn/models/attention.py:276, in Attention._flash_varlen_attention(self, q, k, v, cu_seqlens, max_seqlen, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k)
#     274 # Flatten for flash attention which expects (total_valid_tokens, num_heads, head_dim)
#     275 q_flat, k_flat, v_flat = q.squeeze(0), k.squeeze(0), v.squeeze(0)
# --> 276 out = self.attn(q_flat, k_flat, v_flat, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, window_size=self.window_size)
#     277 return out.view(q.shape[0], -1, self.dim)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:1448, in flash_attn_varlen_func(q, k, v, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p, softmax_scale, causal, window_size, softcap, alibi_slopes, deterministic, return_attn_probs, block_table)
#    1375 def flash_attn_varlen_func(
#    1376     q,
#    1377     k,
#    (...)
#    1391     block_table=None,
#    1392 ):
#    1393     """dropout_p should be set to 0.0 during evaluation
#    1394     Supports multi-query and grouped-query attention (MQA/GQA) by passing in K, V with fewer heads
#    1395     than Q. Note that the number of heads in Q must be divisible by the number of heads in KV.
#    (...)
#    1446             pattern (negative means that location was dropped, nonnegative means it was kept).
#    1447     """
# -> 1448     return FlashAttnVarlenFunc.apply(
#    1449         q,
#    1450         k,
#    1451         v,
#    1452         cu_seqlens_q,
#    1453         cu_seqlens_k,
#    1454         max_seqlen_q,
#    1455         max_seqlen_k,
#    1456         dropout_p,
#    1457         softmax_scale,
#    1458         causal,
#    1459         window_size,
#    1460         softcap,
#    1461         alibi_slopes,
#    1462         deterministic,
#    1463         return_attn_probs,
#    1464         block_table,
#    1465         torch.is_grad_enabled(),
#    1466     )
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:930, in FlashAttnVarlenFunc.forward(ctx, q, k, v, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p, softmax_scale, causal, window_size, softcap, alibi_slopes, deterministic, return_softmax, block_table, is_grad_enabled)
#     928     k = torch.nn.functional.pad(k, [0, 8 - head_size_og % 8])
#     929     v = torch.nn.functional.pad(v, [0, 8 - head_size_og % 8])
# --> 930 out_padded, softmax_lse, S_dmask, rng_state = _wrapped_flash_attn_varlen_forward(
#     931     q,
#     932     k,
#     933     v,
#     934     cu_seqlens_q,
#     935     cu_seqlens_k,
#     936     max_seqlen_q,
#     937     max_seqlen_k,
#     938     dropout_p,
#     939     softmax_scale,
#     940     causal=causal,
#     941     window_size_left=window_size[0],
#     942     window_size_right=window_size[1],
#     943     softcap=softcap,
#     944     alibi_slopes=alibi_slopes,
#     945     return_softmax=return_softmax and dropout_p > 0,
#     946     block_table=block_table,
#     947 )
#     948 if is_grad:
#     949     ctx.save_for_backward(
#     950         q, k, v, out_padded, softmax_lse, cu_seqlens_q, cu_seqlens_k, rng_state
#     951     )
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_ops.py:1123, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1121 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1122     return _call_overload_packet_from_python(self, args, kwargs)
# -> 1123 return self._op(*args, **(kwargs or {}))
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_library/autograd.py:113, in make_autograd_impl.<locals>.autograd_impl(keyset, *args, **keyword_only_args)
#     111     result = Generated.apply(*args, Metadata(keyset, keyword_only_args))  # type: ignore[attr-defined]
#     112 else:
# --> 113     result = forward_no_grad(*args, Metadata(keyset, keyword_only_args))
#     114 return result
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_library/autograd.py:40, in make_autograd_impl.<locals>.forward_no_grad(*args)
#      38 keyset = metadata.keyset
#      39 kwargs = metadata.keyword_only_args
# ---> 40 result = op.redispatch(keyset & _C._after_autograd_keyset, *args, **kwargs)
#      41 return result
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_ops.py:728, in OpOverload.redispatch(self, keyset, *args, **kwargs)
#     727 def redispatch(self, /, keyset, *args, **kwargs):
# --> 728     return self._handle.redispatch_boxed(keyset, *args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_library/custom_ops.py:305, in CustomOpDef.register_kernel.<locals>.inner.<locals>.backend_impl(*args, **kwargs)
#     304 def backend_impl(*args, **kwargs):
# --> 305     result = self._backend_fns[device_type](*args, **kwargs)
#     307     def get_module():
#     308         fn = self._backend_fns[device_type]
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_compile.py:32, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      29     disable_fn = torch._dynamo.disable(fn, recursive)
#      30     fn.__dynamo_disable = disable_fn
# ---> 32 return disable_fn(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:745, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     741 prior_skip_guard_eval_unsafe = set_skip_guard_eval_unsafe(
#     742     _is_skip_guard_eval_unsafe_stance()
#     743 )
#     744 try:
# --> 745     return fn(*args, **kwargs)
#     746 finally:
#     747     _maybe_set_eval_frame(prior)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/_library/custom_ops.py:337, in CustomOpDef.register_kernel.<locals>.inner.<locals>.wrapped_fn(*args, **kwargs)
#     335     return self._init_fn(*args, **kwargs)
#     336 else:
# --> 337     return fn(*args, **kwargs)
#
# File /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:170, in _flash_attn_varlen_forward(q, k, v, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p, softmax_scale, causal, window_size_left, window_size_right, softcap, alibi_slopes, return_softmax, block_table, leftpad_k, seqused_k, zero_tensors)
#     147 @_torch_custom_op_wrapper("flash_attn::_flash_attn_varlen_forward", mutates_args=(), device_types="cuda")
#     148 def _flash_attn_varlen_forward(
#     149     q: torch.Tensor,
#    (...)
#     167     zero_tensors: bool = False,
#     168 ) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
#     169     q, k, v = [maybe_contiguous(x) for x in (q, k, v)]
# --> 170     out, softmax_lse, S_dmask, rng_state = flash_attn_gpu.varlen_fwd(
#     171         q,
#     172         k,
#     173         v,
#     174         None,
#     175         cu_seqlens_q,
#     176         cu_seqlens_k,
#     177         seqused_k,
#     178         leftpad_k,
#     179         block_table,
#     180         alibi_slopes,
#     181         max_seqlen_q,
#     182         max_seqlen_k,
#     183         dropout_p,
#     184         softmax_scale,
#     185         zero_tensors,
#     186         causal,
#     187         window_size_left,
#     188         window_size_right,
#     189         softcap,
#     190         return_softmax,
#     191         None,
#     192     )
#     193     # if out.isnan().any() or softmax_lse.isnan().any():
#     194     #     breakpoint()
#     195     return out, softmax_lse, S_dmask, rng_state
#
# RuntimeError: FlashAttention only support fp16 and bf16 data type
# Exception raised from mha_varlen_fwd at /home/runner/work/flash-attention/flash-attention/csrc/flash_attn/flash_api.cpp:545 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >) + 0x98 (0x14bbc06b1788 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libc10.so)
# frame #1: c10::detail::torchCheckFail(char const*, char const*, unsigned int, char const*) + 0x6a (0x14bbc065afbc in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libc10.so)
# frame #2: flash::mha_varlen_fwd(at::Tensor&, at::Tensor const&, at::Tensor const&, std::optional<at::Tensor>&, at::Tensor const&, at::Tensor const&, std::optional<at::Tensor>&, std::optional<at::Tensor const>&, std::optional<at::Tensor>&, std::optional<at::Tensor>&, int, int, float, float, bool, bool, int, int, float, bool, std::optional<at::Generator>) + 0x1abe (0x14ba88f511ce in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn_2_cuda.cpython-311-x86_64-linux-gnu.so)
# frame #3: <unknown function> + 0x1c3639 (0x14ba88f6f639 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn_2_cuda.cpython-311-x86_64-linux-gnu.so)
# frame #4: <unknown function> + 0x1bd2a4 (0x14ba88f692a4 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/flash_attn_2_cuda.cpython-311-x86_64-linux-gnu.so)
# frame #5: <unknown function> + 0x201b06 (0x5623c0496b06 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #6: _PyObject_MakeTpCall + 0x253 (0x5623c04758b3 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #7: _PyEval_EvalFrameDefault + 0x716 (0x5623c04833b6 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #8: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #9: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #10: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #11: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #12: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #13: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #14: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #15: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #16: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #17: <unknown function> + 0x9146fa (0x14bba35716fa in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #18: <unknown function> + 0xc154af (0x14bba38724af in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #19: <unknown function> + 0xc08c86 (0x14bba3865c86 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #20: <unknown function> + 0xc091e4 (0x14bba38661e4 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #21: <unknown function> + 0x42f18c (0x14bba308c18c in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #22: <unknown function> + 0x201b06 (0x5623c0496b06 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #23: _PyObject_MakeTpCall + 0x253 (0x5623c04758b3 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #24: <unknown function> + 0x2301b6 (0x5623c04c51b6 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #25: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #26: <unknown function> + 0x22ffc2 (0x5623c04c4fc2 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #27: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #28: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #29: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #30: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #31: <unknown function> + 0xc14ad3 (0x14bba3871ad3 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #32: <unknown function> + 0xc1545a (0x14bba387245a in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #33: <unknown function> + 0x58018a1 (0x14bb7d7048a1 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_cpu.so)
# frame #34: torch::jit::invokeOperatorFromPython(std::vector<std::shared_ptr<torch::jit::Operator>, std::allocator<std::shared_ptr<torch::jit::Operator> > > const&, pybind11::args const&, pybind11::kwargs const&, std::optional<c10::DispatchKey>) + 0xef (0x14bba362170f in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #35: torch::jit::_get_operation_for_overload_or_packet(std::vector<std::shared_ptr<torch::jit::Operator>, std::allocator<std::shared_ptr<torch::jit::Operator> > > const&, c10::Symbol, pybind11::args const&, pybind11::kwargs const&, bool, std::optional<c10::DispatchKey>) + 0x231 (0x14bba36219c1 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #36: <unknown function> + 0x8c9394 (0x14bba3526394 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #37: <unknown function> + 0x42f18c (0x14bba308c18c in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #38: <unknown function> + 0x201b06 (0x5623c0496b06 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #39: PyObject_Call + 0xbe (0x5623c04b063e in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #40: _PyEval_EvalFrameDefault + 0x8c34 (0x5623c048b8d4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #41: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #42: _PyObject_FastCallDictTstate + 0xe0 (0x5623c047a420 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #43: _PyObject_Call_Prepend + 0xe9 (0x5623c04ae419 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #44: <unknown function> + 0x2eb108 (0x5623c0580108 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #45: _PyObject_MakeTpCall + 0x253 (0x5623c04758b3 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #46: _PyEval_EvalFrameDefault + 0x716 (0x5623c04833b6 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #47: _PyFunction_Vectorcall + 0x181 (0x5623c04a6981 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #48: THPFunction_apply(_object*, _object*) + 0xe24 (0x14bba33f6cd4 in /usr/wipp/conda/24.5.0u/envs/common/lib/python3.11/site-packages/torch/lib/libtorch_python.so)
# frame #49: <unknown function> + 0x201b28 (0x5623c0496b28 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #50: PyObject_Call + 0xbe (0x5623c04b063e in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #51: _PyEval_EvalFrameDefault + 0x8c34 (0x5623c048b8d4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #52: <unknown function> + 0x2308d4 (0x5623c04c58d4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #53: <unknown function> + 0x2300be (0x5623c04c50be in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #54: PyObject_Call + 0x130 (0x5623c04b06b0 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #55: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #56: <unknown function> + 0x2308d4 (0x5623c04c58d4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #57: <unknown function> + 0x2300be (0x5623c04c50be in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #58: PyObject_Call + 0x130 (0x5623c04b06b0 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #59: _PyEval_EvalFrameDefault + 0x4a44 (0x5623c04876e4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #60: <unknown function> + 0x2308d4 (0x5623c04c58d4 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #61: <unknown function> + 0x2300be (0x5623c04c50be in /usr/wipp/conda/24.5.0u/envs/common/bin/python)
# frame #62: PyObject_Call + 0x130 (0x5623c04b06b0 in /usr/wipp/conda/24.5.0u/envs/common/bin/python)

# %%
import numpy as np

pv = reco_data["pred_valid"].astype(bool)
tv = reco_data["truth_valid"].astype(bool)
mask = pv & tv

pred_pt = reco_data["pred_pt"][mask]
truth_pt = reco_data["truth_pt"][mask]

print("paired entries:", pred_pt.size)
print("pred_pt unique rounded 0.01:", np.unique(np.round(pred_pt, 2)).shape[0])
print("truth_pt unique rounded 0.01:", np.unique(np.round(truth_pt, 2)).shape[0])
print("pred_pt percentiles [1,50,99,99.9]:", np.percentile(pred_pt, [1, 50, 99, 99.9]))
print("truth_pt percentiles [1,50,99,99.9]:", np.percentile(truth_pt, [1, 50, 99, 99.9]))

# Show dominant repeated predicted pt values
vals, cnt = np.unique(np.round(pred_pt, 2), return_counts=True)
idx = np.argsort(cnt)[::-1][:12]
print("Top repeated pred_pt values (rounded 0.01):")
for v, c in zip(vals[idx], cnt[idx]):
    print(f"  {v:8.2f}: {c}")
# Out:
# paired entries: 97078
# pred_pt unique rounded 0.01: 386
# truth_pt unique rounded 0.01: 3421
# pred_pt percentiles [1,50,99,99.9]: [1.00000000e+00 4.83468390e+00 6.71206360e+01 3.93700775e+06]
# truth_pt percentiles [1,50,99,99.9]: [nan nan nan nan]
# Top repeated pred_pt values (rounded 0.01):
#       4.83: 47590
#      11.54: 26238
#      21.13: 10514
#       1.00: 9590
#      33.58: 1409
#      48.92: 416
#       1.95: 208
#      67.12: 167
#      88.20: 142
#     112.15: 55
#     138.98: 19
#     168.68: 10

# %%
reco_data['pred_pt']
# Out:
# array([[7.49297058e+02, 2.11263790e+01, 4.83468390e+00, ...,
#         4.83468390e+00, 1.00000000e+00, 1.00000000e+00],
#        [2.09419512e+06, 2.11263790e+01, 2.11263790e+01, ...,
#         1.00000000e+00, 1.00000000e+00, 4.83468390e+00],
#        [2.39624414e+03, 1.15435705e+01, 1.15435705e+01, ...,
#         1.00000000e+00, 4.83468390e+00, 1.00000000e+00],
#        ...,
#        [8.16190900e+06, 4.83468390e+00, 1.15435705e+01, ...,
#         4.83468390e+00, 4.83468390e+00, 4.83468390e+00],
#        [1.82582375e+06, 1.95323825e+00, 1.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [2.02269219e+05, 4.83468390e+00, 1.15435705e+01, ...,
#         4.83468390e+00, 4.83468390e+00, 1.15435705e+01]],
#       shape=(700, 400), dtype=float32)

# %%
import torch
import numpy as np

dev = next(model.parameters()).device
raw_vals = []
for bi, (inp, tgt) in enumerate(loader):
    if bi >= 3:
        break
    inp = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in inp.items()}
    tgt = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in tgt.items()}
    with torch.no_grad(), torch.autocast(device_type="cuda", dtype=torch.bfloat16):
        out = model.model(inp, targets=tgt)
        pred = model.model.predict(out)
    raw_pt = pred["reco_final"]["regression"]["reco_pflow_pt"].detach().cpu().float()
    tv = tgt["reco_particle_valid"].detach().cpu().bool()
    raw_vals.append(raw_pt[tv].numpy())

raw_vals = np.concatenate(raw_vals)
vals, cnt = np.unique(np.round(raw_vals, 3), return_counts=True)
idx = np.argsort(cnt)[::-1][:12]
print("raw reco_pflow_pt unique rounded 1e-3:", vals.shape[0])
print("top repeated raw values:")
for v, c in zip(vals[idx], cnt[idx]):
    print(f"  {v:8.3f}: {c}")
# Out:
# raw reco_pflow_pt unique rounded 1e-3: 141
# top repeated raw values:
#     -0.996: 9214
#     -1.000: 6665
#     -0.992: 3947
#     -0.988: 1272
#     -1.008: 270
#     -0.984: 185
#     -0.980: 48
#     -0.977: 21
#     -1.016: 14
#     -0.973: 12
#     -1.023: 8
#     -0.969: 8

# %%
import torch
import numpy as np

dev = next(model.parameters()).device
inp, tgt = next(iter(loader))
inp = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in inp.items()}
tgt = {k: v.to(dev) if isinstance(v, torch.Tensor) else v for k, v in tgt.items()}

with torch.no_grad(), torch.autocast(device_type="cuda", dtype=torch.bfloat16):
    out = model.model(inp, targets=tgt)
    pred = model.model.predict(out)

tv = tgt["reco_particle_valid"].detach().cpu().bool()
reg = pred["reco_final"]["regression"]

raw_pt = reg["reco_pflow_pt"].detach().cpu().float()[tv].numpy()
proxy_pt = reg["reco_pflow_proxy_pt"].detach().cpu().float()[tv].numpy()

print("raw reco_pflow_pt unique(1e-3):", np.unique(np.round(raw_pt, 3)).shape[0])
print("raw proxy_pt unique(1e-3):     ", np.unique(np.round(proxy_pt, 3)).shape[0])
print("raw reco_pflow_pt p50/p99:", np.percentile(raw_pt, [50, 99]))
print("raw proxy_pt p50/p99:    ", np.percentile(proxy_pt, [50, 99]))
# Out:
# raw reco_pflow_pt unique(1e-3): 61
# raw proxy_pt unique(1e-3):      28
# raw reco_pflow_pt p50/p99: [-0.99609375 -0.984375  ]
# raw proxy_pt p50/p99:     [-0.99609375 -0.984375  ]
