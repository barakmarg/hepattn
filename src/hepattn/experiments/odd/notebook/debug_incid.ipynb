# %%
cd /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd/notebook
# Out:
# /storage/agrp/barakma/hepattn/src/hepattn/experiments/odd/notebook

# %%
import pickle
with open('c_inc.pkl', 'rb') as f:
    c_inc = pickle.load(f)

with open('charged_inc.pkl', 'rb') as f:
    charged = pickle.load(f)

# %%
charged.shape
# Out:
# (32, 450, 600)

# %%
charged.shape
# Out:
# (32, 450, 600)

# %%
import matplotlib.pyplot as plt

# Select the first example in the batch
incidence_matrix = charged[1]  # Shape: (450, 600) -> (number_of_particles, tracks)

plt.figure(figsize=(12, 8))
plt.imshow(incidence_matrix, aspect='auto', cmap='viridis', origin='lower')
plt.colorbar(label='Incidence Weight')
plt.title('Incidence Matrix Heatmap for First Batch (Particles x Tracks)')
plt.xlabel('Track Index')
plt.ylabel('Particle Index')
plt.show()
